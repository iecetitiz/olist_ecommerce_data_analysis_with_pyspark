# %% [markdown]
# # OLIST E-COMMERCE DATA ANALYSIS

# %% [markdown]
# ## Data Cleaning and Transformation
# ✅ Data quality assessment (identifying NULLs and duplicates)
# ✅ Cleaning and standardizing geographic (City/State) and textual data
# ✅ Validating logical consistency

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as F

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
spark = SparkSession.builder.appName("Olist Ecommerce Preprocessing").master("local[2]").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/16 16:52:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # GEOLOCATION

# %%
# --- Define Geolocation Schema ---
# Zip_code is StringType to preserve leading zeros, essential for Brazilian CEPs(Postal Addressing Code).
# Latitude and Longitude are DoubleType for high-precision coordinate math.
geo_schema = StructType([
    StructField("geolocation_zip_code_prefix", StringType(), True),
    StructField("geolocation_lat", DoubleType(), True),
    StructField("geolocation_lng", DoubleType(), True),
    StructField("geolocation_city", StringType(), True),
    StructField("geolocation_state", StringType(), True)
])

# --- Load Geolocation Dataset ---
geolocation = spark.read.format("csv") \
    .schema(geo_schema) \
    .option("header", "true") \
    .option("sep", ",") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("encoding", "UTF-8") \
    .option("multiLine", "true") \
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_geolocation_dataset.csv")

# %%
# Display schema
geolocation.printSchema()
# Out:
# root
#  |-- geolocation_zip_code_prefix: string (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)

# %%
# Total number of records in the geolocation dataset
geolocation.count()
# Out:
# 1000163

# %%
# Show first 5 rows
geolocation.limit(5).toPandas()
# Out:
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       01037       -23.545621       -46.639292
# 1                       01046       -23.546081       -46.644820
# 2                       01046       -23.546129       -46.642951
# 3                       01041       -23.544392       -46.639499
# 4                       01035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ### Trim String Columns

# %%
def trim_and_nullify_strings(df):
    """
    Cleans all string columns by:
    1. Trimming whitespace
    2. Converting to lowercase
    3. Converting empty strings to NULL (None)
    """
    clean_df = df.select([
        F.when(F.trim(F.col(c)) == "", None)                # If trimmed value is empty -> make it NULL
         .otherwise(F.lower(F.trim(F.col(c))))              # Otherwise -> keep the trimmed value and make them lowercase
         .alias(c)
        if t == 'string' else F.col(c) # Only apply this logic to string columns
        for c, t in df.dtypes
    ])
    
    return clean_df

# %%
# Cleans the geolocation dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
geolocation_nullified_trimmed = trim_and_nullify_strings(geolocation)

# %% [markdown]
# ### Normalize Brazilian Characters

# %%
import unicodedata

# This function uses Unicode Normalization Form D (NFD) to separate 
# characters from their accent marks, then filters out the marks.

# Removes accents and diacritics from a string (e.g., converts 'á' to 'a').

def strip_accents(text):
    if text is None:
        return None
    # Normalize to NFD (decomposes characters like 'ã' into 'a' + '~')
    # Then filter out the non-spacing mark (the accent)
    return "".join(c for c in unicodedata.normalize('NFD', text)
                   if unicodedata.category(c) != 'Mn')

# Register as a UDF
strip_accents_udf = F.udf(strip_accents)

# %%
# Remove accents to ensure 'são paulo' and 'sao paulo' are treated as the same city
geolocation_normalized_brazilian_characters = geolocation_nullified_trimmed.withColumn(
    "geolocation_city_clean",
    strip_accents_udf(F.col("geolocation_city"))
)

# %%
# Validation: Check for city names that still contain special characters (not a-z or space)
# to verify if the normalization function was successful.
geolocation_normalized_brazilian_characters.filter(F.col("geolocation_city").rlike(r"[^a-z\s]")) \
    .select("geolocation_city", "geolocation_city_clean").distinct() \
    .toPandas().head()
# Out:
#   geolocation_city geolocation_city_clean
# 0        são paulo              sao paulo
# 1          olímpia                olimpia
# 2         sobrália               sobralia
# 3          açucena                acucena
# 4     olhos d'água           olhos d'agua

# %% [markdown]
# ### Handling Hyphenated City Entries

# %%
# Normalizes string formatting by replacing hyphens with spaces, 
# collapsing multiple spaces into one, and trimming edges.
    
def clean_spacing_and_hyphens(col_name):
    # 1. Replace hyphens (-) with a single space
    step1 = F.regexp_replace(F.col(col_name), "-", " ")
    
    # 2. Replace 2 or more consecutive spaces with a single space
    # \s+ means "one or more whitespace characters"
    step2 = F.regexp_replace(step1, r"\s+", " ")
    
    return F.trim(step2)

# %%
# Remove hyphens and multiple spaces
geolocation_cleaned_spacing_and_hyphens = geolocation_normalized_brazilian_characters.withColumn(
    "geolocation_city_clean", 
    clean_spacing_and_hyphens("geolocation_city_clean")
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(geolocation_cleaned_spacing_and_hyphens
    .filter(F.col("geolocation_city").like("%-%"))
    .select("geolocation_city", "geolocation_city_clean")
    .distinct()
).toPandas()
# Out:
#                      geolocation_city           geolocation_city_clean
# 0                      biritiba-mirim                   biritiba mirim
# 1                         colônia z-3                      colonia z 3
# 2                         entre-ijuís                      entre ijuis
# 3                          embu-guaçu                       embu guacu
# 4       bacaxa (saquarema) - distrito      bacaxa (saquarema) distrito
# 5                       sapucaí-mirim                    sapucai mirim
# 6          venda nova do imigrante-es       venda nova do imigrante es
# 7                          mogi-mirim                       mogi mirim
# 8                           ji-parana                        ji parana
# 9                         colonia z-3                      colonia z 3
# 10              olho-d'agua do borges            olho d'agua do borges
# 11                        ceará-mirim                      ceara mirim
# 12                       pingo-d'agua                     pingo d'agua
# 13                          peixe-boi                        peixe boi
# 14                          varre-sai                        varre sai
# 15          vitorinos - alto rio doce          vitorinos alto rio doce
# 16                        ceara-mirim                      ceara mirim
# 17                       pingo-d agua                     pingo d agua
# 18              conceição do lago-açu            conceicao do lago acu
# 19                      pariquera-açu                    pariquera acu
# 20                      guajará-mirim                    guajara mirim
# 21                        xique-xique                      xique xique
# 22                         guarda-mor                       guarda mor
# 23                        igarapé-açu                      igarape acu
# 24         governador dix-sept rosado       governador dix sept rosado
# 25                       igarapé-miri                     igarape miri
# 26                      pariquera-acu                    pariquera acu
# 27                         mogi-guacu                       mogi guacu
# 28  monte gordo (camacari) - distrito  monte gordo (camacari) distrito
# 29                          xangri-la                        xangri la
# 30                          ji-paraná                        ji parana
# 31                       guarulhos-sp                     guarulhos sp
# 32                        igarape-acu                      igarape acu
# 33                          venha-ver                        venha ver
# 34   praia grande (fundão) - distrito   praia grande (fundao) distrito
# 35                    itapecuru-mirim                  itapecuru mirim
# 36                      pindaré-mirim                    pindare mirim
# 37                       nao-me-toque                     nao me toque
# 38                         apicum-acu                       apicum acu
# 39                      naque-nanuque                    naque nanuque
# 40                           tomé-açu                         tome acu
# 41                            vau-acu                          vau acu
# 42                        entre-ijuis                      entre ijuis
# 43              olho-d'água do borges            olho d'agua do borges
# 44                          arco-iris                        arco iris
# 45                       igarape-miri                     igarape miri
# 46                          xangri-lá                        xangri la
# 47              olho-d agua do borges            olho d agua do borges
# 48                      sapucai-mirim                    sapucai mirim
# 49                           tomé-açú                         tome acu
# 50              conceicao do lago-acu            conceicao do lago acu
# 51                      guajara-mirim                    guajara mirim
# 52                       olhos-d agua                     olhos d agua
# 53                         embu-guacu                       embu guacu
# 54                           tome-acu                         tome acu
# 55                       não-me-toque                     nao me toque

# %% [markdown]
# ### Regional Naming Normalization

# %%
def normalize_doeste_and_others(col_name):
    # 1. Basic cleaning: lowercase and trim
    c = F.lower(F.trim(F.col(col_name)))
    
    
    # 2. Decode HTML apostrophes (%26apos%3b)
    c = F.regexp_replace(c, "%26apos%3b", " ")
    
    # 3. The Updated Concatenation Regex (No Group 1)
    # (d)                -> Group 1: The connector ('d')
    # [^a-z]+            -> The "messy" separator (spaces, hyphens, symbols, etc.)
    # (agua|alho|...)    -> Group 2: All your target words
    # We use $1$2 to join the 'd' directly to the word (e.g., 'd' + 'oeste' = 'doeste')
    pattern = r"(d)[^a-z]+(agua|alho|alianca|arco|abadia|ajuda|alcantara|avila|oeste|arca|anta)"
    
    # Replacement: $1 (d) + $2 (target word)
    return F.regexp_replace(c, pattern, "$1$2")

# %%
# Refines specific regional naming conventions by mapping variations like "d' oeste" 
# to a standardized format, ensuring consistent grouping across the 'geolocation_city_clean' column.
geolocation_normalized_doeste_and_others = geolocation_cleaned_spacing_and_hyphens.withColumn(
    "geolocation_city_clean", 
    normalize_doeste_and_others("geolocation_city_clean")
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.

# Define the pattern for specialized regional naming and characters
special_cities_pattern = "agua|alho|alianca|arco|abadia|ajuda|alcantara|avila|oeste|arca|anta"

# Filter for rows that match normalization criteria
(geolocation_normalized_doeste_and_others
    .filter(F.col("geolocation_city").rlike(special_cities_pattern))
    .select("geolocation_city", "geolocation_city_clean")
    .distinct()
).toPandas().head(20)
# Out:
#            geolocation_city   geolocation_city_clean
# 0                  ouroeste                 ouroeste
# 1           limeira d oeste           limeira doeste
# 2      floresta do araguaia     floresta do araguaia
# 3        sao joao d alianca        sao joao dalianca
# 4         são joão do oeste        sao joao do oeste
# 5      santa rita de cássia     santa rita de cassia
# 6                    taguaí                   taguai
# 7                 paraguacu                paraguacu
# 8             cícero dantas            cicero dantas
# 9      santa bárbara do sul     santa barbara do sul
# 10             olhos d'agua              olhos dagua
# 11   santa maria do cambucá   santa maria do cambuca
# 12  central de santa helena  central de santa helena
# 13    santa maria de jetibá    santa maria de jetiba
# 14        paraiso das aguas        paraiso das aguas
# 15                    garca                    garca
# 16     santa rita do itueto     santa rita do itueto
# 17        santa fe de goias        santa fe de goias
# 18    são sebastião do anta    sao sebastiao do anta
# 19            tres aliancas            tres aliancas

# %% [markdown]
# ### Removing Parentheses

# %%
# There are some rows where geolocation_city contains '(' or ')'

# Filter for rows where geolocation_city contains '(' or ')'
df_with_parentheses = geolocation_normalized_doeste_and_others.filter(F.col("geolocation_city").rlike(r"\(|\)"))

# Show the distinct results to see what kind of data is there
df_with_parentheses.select("geolocation_city").distinct().toPandas()
# Out:
#                         geolocation_city
# 0       praia grande (fundão) - distrito
# 1                    tamoios (cabo frio)
# 2      monte gordo (camacari) - distrito
# 3                      jacare (cabreuva)
# 4          bacaxa (saquarema) - distrito
# 5   california da barra (barra do pirai)
# 6                      jacaré (cabreúva)
# 7                     realeza (manhuacu)
# 8                   antunes (igaratinga)
# 9                      penedo (itatiaia)
# 10                     itabatan (mucuri)

# %% [markdown]
# 📍 The text outside the parentheses is retained because it represents the specific city or district name (e.g., 'bacaxa'). The text inside typically refers to the parent municipality (e.g., 'saquarema'), which becomes redundant when a separate municipality or state column already exists.

# %%
def remove_parentheses(col_name):
    # 1. Basic cleaning: lowercase and trim
    c = F.lower(F.trim(F.col(col_name)))
    
    # 2. Remove the first parenthesis and everything after it
    # \s* -> matches any leading spaces
    # \(    -> matches the opening parenthesis
    # .* -> matches everything until the end of the string
    c = F.regexp_replace(c, r"\s*\(.*", "")
    
    # 3. Final Polish: trim any unexpected trailing spaces
    return F.trim(c)

# %%
# Apply the 'remove_parentheses' function to normalize the city names
geolocation_removed_parentheses = geolocation_normalized_doeste_and_others\
    .withColumn("geolocation_city_clean", remove_parentheses("geolocation_city_clean"))

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(geolocation_removed_parentheses\
    .filter(F.col("geolocation_city").contains("("))
    .select("geolocation_city", "geolocation_city_clean")
    .distinct()).toPandas()
# Out:
#                         geolocation_city geolocation_city_clean
# 0       praia grande (fundão) - distrito           praia grande
# 1      monte gordo (camacari) - distrito            monte gordo
# 2                      jacaré (cabreúva)                 jacare
# 3                      jacare (cabreuva)                 jacare
# 4          bacaxa (saquarema) - distrito                 bacaxa
# 5                      itabatan (mucuri)               itabatan
# 6                   antunes (igaratinga)                antunes
# 7   california da barra (barra do pirai)    california da barra
# 8                      penedo (itatiaia)                 penedo
# 9                     realeza (manhuacu)                realeza
# 10                   tamoios (cabo frio)                tamoios

# %% [markdown]
# ### Cleaning Special Characters

# %%
# There are still special characters to fix
# Filters for city names containing special characters (not a-z or space)
geolocation_removed_parentheses.filter(F.col("geolocation_city_clean").rlike(r"[^a-z\s]")) \
    .select("geolocation_city", "geolocation_city_clean").distinct() \
    .toPandas()
# Out:
#                           geolocation_city  \
# 0                               sa£o paulo
# 1                              colônia z-3
# 2                              colonia z-3
# 3                     florian&oacute;polis
# 4                             ´teresopolis
# 5                            4º centenario
# 6                                  maceia³
# 7                   quilometro 14 do mutum
# 8                           riacho fundo 2
# 9                   sant'ana do livramento
# 10  rio de janeiro, rio de janeiro, brasil
# 11                      ...arraial do cabo
# 12  campo alegre de lourdes, bahia, brasil
# 13                          4o. centenario
# 14                                * cidade
#
#                     geolocation_city_clean
# 0                               sa£o paulo
# 1                              colonia z 3
# 2                              colonia z 3
# 3                     florian&oacute;polis
# 4                             ´teresopolis
# 5                            4º centenario
# 6                                  maceia³
# 7                   quilometro 14 do mutum
# 8                           riacho fundo 2
# 9                   sant'ana do livramento
# 10  rio de janeiro, rio de janeiro, brasil
# 11                      ...arraial do cabo
# 12  campo alegre de lourdes, bahia, brasil
# 13                          4o. centenario
# 14                                * cidade

# %% [markdown]
# ✂️ Standardizes city names by splitting at common delimiters ('/', '\\', or ',') and keeping only
# the first part. This removes redundant geographical suffixes like state or country names.
# example: rio de janeiro, rio de janeiro, brasil -> rio de janeiro

# %%
# Split the city names 
geolocation_split_city = geolocation_removed_parentheses.withColumn(
    "geolocation_city_clean",
    F.trim(F.split(F.col("geolocation_city_clean"), r"/|\\|,").getItem(0))
)

# %%
# Validation: Checking if city names with delimiters (/, \, ,) were correctly split.
(geolocation_split_city
    .filter(F.col("geolocation_city").rlike(r"[/\\,]")) 
    .select(
        "geolocation_city",        # The raw original column
        "geolocation_city_clean"   # The new cleaned column
    ).distinct()
).toPandas()
# Out:
#                          geolocation_city   geolocation_city_clean
# 0  rio de janeiro, rio de janeiro, brasil           rio de janeiro
# 1  campo alegre de lourdes, bahia, brasil  campo alegre de lourdes

# %%
# Cleaning special characters 
def clean_special_characters(col_name):
    # 1. Trim
    c = F.trim(F.col(col_name))
    
    # 2. Fix HTML entities (like florian&oacute;polis)
    # This regex looks for '&', followed by letters, and ending with ';'
    c = F.regexp_replace(c, r"&[a-z]+;", "o") 
    
    # 3. Fix encoding errors (like sa£o paulo)
    # If you want to fix 'sao' specifically:
    c = F.regexp_replace(c, "sa£o", "sao")
    
    # 4. Remove leading symbols and punctuation (like * cidade	)
    # Also removes superscripts
    # We keep letters, numbers, and spaces
    c = F.regexp_replace(c, r"[^a-z0-9\s]", " ")
    
    # 5. Fix specific abbreviations (like 4o. in row 19)
    # If '4o' should just be '4'
    c = F.regexp_replace(c, r"(\d+)o\b", "$1")
    
    # 6. Final Polish: remove double spaces and trim again
    return F.trim(F.regexp_replace(c, r"\s+", " "))

# %%
# Apply the 'clean_special_characters' function to normalize the city names
geolocation_remove_special = geolocation_split_city.withColumn("geolocation_city_clean", clean_special_characters("geolocation_city_clean"))

# %%
# Validation: Check for city names to verify if the normalization function was successful.
geolocation_remove_special.filter(F.col("geolocation_city_clean").rlike(r"[^a-z\s]")) \
    .select("geolocation_city", "geolocation_city_clean").distinct() \
    .toPandas()
# Out:
#          geolocation_city  geolocation_city_clean
# 0             colônia z-3             colonia z 3
# 1             colonia z-3             colonia z 3
# 2          4o. centenario            4 centenario
# 3           4º centenario            4 centenario
# 4  quilometro 14 do mutum  quilometro 14 do mutum
# 5          riacho fundo 2          riacho fundo 2

# %% [markdown]
# ### Identifying and Correcting State Codes in City Fields

# %% [markdown]
# 📍 There are city names that are only two letters long.

# %%
# Identify rows where city name is only 2 characters long (likely a state code)
(geolocation_remove_special
    .filter(F.length(F.col("geolocation_city")) < 3)
    .select("geolocation_city", "geolocation_city_clean", "geolocation_state")
    .distinct()
).toPandas()
# Out:
#   geolocation_city geolocation_city_clean geolocation_state
# 0               rj                     rj                rj
# 1               bh                     bh                mg
# 2               sp                     sp                sp

# %%
# Standardize city abbreviations to their full descriptive names
geolocation_cities_fixed_state_codes = geolocation_remove_special.withColumn(
    "geolocation_city_clean",
    F.when(F.col("geolocation_city_clean") == "sp", "sao paulo")
     .when(F.col("geolocation_city_clean") == "rj", "rio de janeiro")
     .when(F.col("geolocation_city_clean") == "bh", "belo horizonte")
     .otherwise(F.col("geolocation_city_clean"))
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(geolocation_cities_fixed_state_codes
    .filter(F.length(F.col("geolocation_city")) < 3)
    .select("geolocation_city", "geolocation_city_clean", "geolocation_state")
    .distinct()
).toPandas()
# Out:
#   geolocation_city geolocation_city_clean geolocation_state
# 0               bh         belo horizonte                mg
# 1               sp              sao paulo                sp
# 2               rj         rio de janeiro                rj

# %% [markdown]
# ### Normalizing Regional Suffixes

# %% [markdown]
# ✂️ This step merges variations of 'do oeste' and 'de alcantara' into a single unified format
# to prevent duplicate city entries (e.g., 'do oeste' to 'doeste').

# %%
# Standardize regional suffixes by merging multi-part names 
geolocation_regional_suffixes = geolocation_cities_fixed_state_codes.withColumn(
    "geolocation_city_clean",
    F.regexp_replace(F.col("geolocation_city_clean"), r"do\s+oeste", "doeste")
).withColumn(
    "geolocation_city_clean",
    F.regexp_replace(F.col("geolocation_city_clean"), r"de\s+alcantara", "dalcantara")
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(geolocation_regional_suffixes
    .filter(F.col("geolocation_city").rlike("do oeste|de alcantara"))
    .select("geolocation_city", "geolocation_city_clean")
    .distinct()
).toPandas()
# Out:
#            geolocation_city geolocation_city_clean
# 0         cruzeiro do oeste        cruzeiro doeste
# 1    sao sebastiao do oeste   sao sebastiao doeste
# 2        sao jorge do oeste       sao jorge doeste
# 3       ouro preto do oeste      ouro preto doeste
# 4          iracema do oeste         iracema doeste
# 5        vera cruz do oeste       vera cruz doeste
# 6          limeira do oeste         limeira doeste
# 7    dom pedro de alcantara   dom pedro dalcantara
# 8       sao miguel do oeste      sao miguel doeste
# 9       limeira do oeste mg      limeira doeste mg
# 10      luizlandia do oeste      luizlandia doeste
# 11           união do oeste           uniao doeste
# 12        tuneiras do oeste        tuneiras doeste
# 13     são gabriel do oeste     sao gabriel doeste
# 14   são francisco do oeste   sao francisco doeste
# 15          itapua do oeste          itapua doeste
# 16   sao pedro de alcantara   sao pedro dalcantara
# 17    sao lourenco do oeste    sao lourenco doeste
# 18        alvorada do oeste        alvorada doeste
# 19    olhos d'agua do oeste     olhos dagua doeste
# 20        são joão do oeste        sao joao doeste
# 21             rio do oeste             rio doeste
# 22   são sebastião do oeste   sao sebastiao doeste
# 23      santa rita do oeste      santa rita doeste
# 24   alta floresta do oeste   alta floresta doeste
# 25     pimenteiras do oeste     pimenteiras doeste
# 26      luizlândia do oeste      luizlandia doeste
# 27           ipora do oeste           ipora doeste
# 28      são miguel do oeste      sao miguel doeste
# 29    santa izabel do oeste    santa izabel doeste
# 30    santa tereza do oeste    santa tereza doeste
# 31      entre rios do oeste      entre rios doeste
# 32  novo horizonte do oeste  novo horizonte doeste
# 33           uniao do oeste           uniao doeste
# 34         espigão do oeste         espigao doeste
# 35     santa maria do oeste     santa maria doeste
# 36           iporã do oeste           ipora doeste
# 37         espigao do oeste         espigao doeste
# 38        colorado do oeste        colorado doeste
# 39    são lourenço do oeste    sao lourenco doeste
# 40         formosa do oeste         formosa doeste
# 41     sao gabriel do oeste     sao gabriel doeste
# 42   sao francisco do oeste   sao francisco doeste
# 43      ouro verde do oeste      ouro verde doeste
# 44        sao joao do oeste        sao joao doeste

# %% [markdown]
# ### Removing Trailing State Abbreviations

# %% [markdown]
# ✂️ Some rows have a state abbreviation at the end of the line (e.g., 'franca sp'),
# while others have suffix characters that are not state codes, like 'santa fe'.

# %%
# Inspect rows where 'geolocation_city' contains a state code at the end of the string.
(geolocation_regional_suffixes
    .filter(F.col("geolocation_city").rlike(r"\s[a-z]{2}$"))
    .select("geolocation_city", "geolocation_city_clean", "geolocation_state")
    .distinct()
).toPandas()
# Out:
#        geolocation_city geolocation_city_clean geolocation_state
# 0             franca sp              franca sp                sp
# 1           maria da fe            maria da fe                mg
# 2       coronel joao sa        coronel joao sa                ba
# 3           holambra ii            holambra ii                sp
# 4              sento se               sento se                ba
# 5          francisco sa           francisco sa                mg
# 6              pedro ii               pedro ii                pi
# 7                pio ix                 pio ix                pi
# 8   limeira do oeste mg      limeira doeste mg                mg
# 9            senador sa             senador sa                ce
# 10            lavras mg              lavras mg                mg
# 11             santa fe               santa fe                pr
# 12   bonito de santa fe     bonito de santa fe                pb

# %%
# This pattern only matches specific state codes at the end of the string
state_codes_pattern_geolocation = r"\s(mg|sp)$"

geolocation_trailing_state_code = geolocation_regional_suffixes.withColumn(
    "geolocation_city_clean",
    F.regexp_replace(F.col("geolocation_city_clean"), state_codes_pattern_geolocation, "")
)

# %%
# Validation: Check unique examples of city names ending in state codes to ensure correct processing.
(geolocation_trailing_state_code
    .filter(F.col("geolocation_city").rlike(r"\s[a-z]{2}$"))
    .select("geolocation_city", "geolocation_city_clean", "geolocation_state")
    .distinct()
).toPandas()
# Out:
#        geolocation_city geolocation_city_clean geolocation_state
# 0           maria da fe            maria da fe                mg
# 1       coronel joao sa        coronel joao sa                ba
# 2             franca sp                 franca                sp
# 3           holambra ii            holambra ii                sp
# 4              sento se               sento se                ba
# 5          francisco sa           francisco sa                mg
# 6              pedro ii               pedro ii                pi
# 7                pio ix                 pio ix                pi
# 8   limeira do oeste mg         limeira doeste                mg
# 9            senador sa             senador sa                ce
# 10            lavras mg                 lavras                mg
# 11             santa fe               santa fe                pr
# 12   bonito de santa fe     bonito de santa fe                pb

# %% [markdown]
# ### 🕵️  Final validation: Reviewing rows to ensure all cleaning transformations were applied correctly.

# %%
# 🎲 Random Sampling: Selecting 100 unique examples for manual verification
(geolocation_trailing_state_code
    .filter(F.col("geolocation_city").rlike(r"[^a-z\s]"))
    .select("geolocation_city", "geolocation_city_clean")
    .distinct()
    .orderBy(F.rand()) # This shuffles the rows randomly
    .limit(100)        # This picks the first 100 from the shuffle
    .toPandas()
)
# Out:
#              geolocation_city     geolocation_city_clean
# 0          olho d'agua grande          olho dagua grande
# 1                       timbó                      timbo
# 2         são josé do jacuípe        sao jose do jacuipe
# 3     santa vitória do palmar    santa vitoria do palmar
# 4                     colônia                    colonia
# 5                   cipotânea                  cipotanea
# 6          nova santa bárbara         nova santa barbara
# 7               santo antônio              santo antonio
# 8                     piraúba                    pirauba
# 9               bom princípio              bom principio
# 10       conceição do castelo       conceicao do castelo
# 11                  piaçabuçu                  piacabucu
# 12                   pindurão                   pindurao
# 13             andré da rocha             andre da rocha
# 14               firminópolis               firminopolis
# 15   são sebastião dos torres   sao sebastiao dos torres
# 16                     cortês                     cortes
# 17                   miraguaí                   miraguai
# 18                    cabrobó                    cabrobo
# 19               capão bonito               capao bonito
# 20     santo antônio do canaã     santo antonio do canaa
# 21             iporã do oeste               ipora doeste
# 22                      baião                      baiao
# 23                   quatiguá                   quatigua
# 24                   tabaporã                   tabapora
# 25      são geraldo do baixio      sao geraldo do baixio
# 26          são pedro do ivaí          sao pedro do ivai
# 27                 nova canaã                 nova canaa
# 28               francisco sá               francisco sa
# 29                       jóia                       joia
# 30            lambari d'oeste             lambari doeste
# 31   são josé das laranjeiras   sao jose das laranjeiras
# 32      alta floresta d'oeste       alta floresta doeste
# 33                    baraúna                    barauna
# 34    são benedito das areias    sao benedito das areias
# 35                são gonçalo                sao goncalo
# 36          balneário gaivota          balneario gaivota
# 37                    jaraguá                    jaragua
# 38                    araçuaí                    aracuai
# 39                       taió                       taio
# 40               silvanópolis               silvanopolis
# 41                     itaúna                     itauna
# 42                    vau-acu                    vau acu
# 43               pingo-d agua                pingo dagua
# 44                      ubatã                      ubata
# 45       planaltina do paraná       planaltina do parana
# 46       são josé do belmonte       sao jose do belmonte
# 47        bela vista do piauí        bela vista do piaui
# 48   capitão leônidas marques   capitao leonidas marques
# 49         morro de são paulo         morro de sao paulo
# 50                    canguçu                    cangucu
# 51               bonfinópolis               bonfinopolis
# 52                   carambeí                   carambei
# 53          reserva do iguaçu          reserva do iguacu
# 54                  água doce                  agua doce
# 55     são sebastião do passe     sao sebastiao do passe
# 56                  capitólio                  capitolio
# 57                sidrolândia                sidrolandia
# 58                    guarujá                    guaruja
# 59     são sebastião da grama     sao sebastiao da grama
# 60    jaboatão dos guararapes    jaboatao dos guararapes
# 61                 anitápolis                 anitapolis
# 62                lebon régis                lebon regis
# 63              cícero dantas              cicero dantas
# 64      boa vista das missões      boa vista das missoes
# 65          jacare (cabreuva)                     jacare
# 66                   guaiçara                   guaicara
# 67        são pedro do iguaçu        sao pedro do iguacu
# 68  santo antônio do sudoeste  santo antonio do sudoeste
# 69          penedo (itatiaia)                     penedo
# 70          concórdia do pará          concordia do para
# 71                  paulicéia                  pauliceia
# 72          são joão do oeste            sao joao doeste
# 73       cachoeira dos índios       cachoeira dos indios
# 74             nísia floresta             nisia floresta
# 75                    cláudio                    claudio
# 76       são joão do itaperiú       sao joao do itaperiu
# 77                 califórnia                 california
# 78                    turiúba                    turiuba
# 79           castelo do piauí           castelo do piaui
# 80                       apuí                       apui
# 81         são josé dos ramos         sao jose dos ramos
# 82                 cotriguaçu                 cotriguacu
# 83         são josé do jacuri         sao jose do jacuri
# 84                     irapuã                     irapua
# 85                   curimatá                   curimata
# 86        santa cruz cabrália        santa cruz cabralia
# 87        santana do maranhão        santana do maranhao
# 88                      giruá                      girua
# 89              santa bárbara              santa barbara
# 90                brejolândia                brejolandia
# 91                     icapuí                     icapui
# 92                  itanhangá                  itanhanga
# 93              honório serpa              honorio serpa
# 94                   guapiaçu                   guapiacu
# 95                     itaipé                     itaipe
# 96                hidrolândia                hidrolandia
# 97           são josé do ouro           sao jose do ouro
# 98   santa bárbara do tugúrio   santa barbara do tugurio
# 99                    tucuruí                    tucurui

# %% [markdown]
# ### Removing Duplicates

# %%
def check_duplicates(df):
    """
    Checks the dataframe for exact duplicate rows across all columns.

    This function compares the total row count against the distinct row count 
    to identify if any identical records exist in the dataset.
    """
    total_count = df.count()
    unique_count = df.distinct().count()

    if total_count == unique_count:
        print("✅ No exact duplicate rows found. Every row is unique.")
    else:
        duplicate_count = total_count - unique_count
        print(f"⚠️ Warning: Found {duplicate_count} identical duplicate rows.")

# %%
# Final cleanup: Trimming whitespace and converting empty strings to Null.
geolocation_final_trim = trim_and_nullify_strings(geolocation_trailing_state_code)

# %%
check_duplicates(geolocation_final_trim)
# Out:
# [Stage 51:>                                                         (0 + 2) / 2]
# ⚠️ Warning: Found 261831 identical duplicate rows.

# %%
# Removing rows that are 100% identical across all columns
geolocation_drop_duplicates = geolocation_final_trim.dropDuplicates()

# %% [markdown]
# ### 📊 Row Count Comparison

# %%
# 1. Get the initial and final counts
initial_count = geolocation.count()
final_count = geolocation_drop_duplicates.count()

# 2. Calculate the difference (rows removed)
rows_removed = initial_count - final_count
# Calculate the percentage of data removed
reduction_pct = (rows_removed / initial_count) * 100

# 3. Display the results clearly 
print(f"--- Data Cleaning Summary ---")
print(f"Initial Rows:    {initial_count:,}")
print(f"Final Rows:      {final_count:,}")
print(f"Rows Removed:    {rows_removed:,}")
print(f"Data Reduction:  {reduction_pct:.2f}%")
# Out:
# [Stage 58:>                                                         (0 + 1) / 1]
# --- Data Cleaning Summary ---
# Initial Rows:    1,000,163
# Final Rows:      738,332
# Rows Removed:    261,831
# Data Reduction:  26.18%

# %% [markdown]
# ### Missing Values

# %%
def check_missing_values(dataframe):
    """
    Dynamically checks for missing values (Null and NaN) across all columns 
    based on their data types.
    
    This function identifies the data type of each column. For numeric 
    floating-point columns (Double/Float), it checks for both NaN and Null. 
    For all other types, it checks only for Null. It returns a summary 
    table showing counts and percentages.

    Args:
        dataframe (pyspark.sql.DataFrame): The Spark DataFrame to analyze.

    Returns:
        pandas.DataFrame: A summary containing 'missing_count' and 'percentage' for each column.
    """
    # 1. Get the total number of rows
    total_rows = dataframe.count()
    
    # 2. Map column names to their types in a dictionary
    # Example: {'order_id': 'string', 'price': 'double'}
    dtypes_dict = dict(dataframe.dtypes)

    # 3. Create a selection of counts for each column
    null_counts = dataframe.select([
        F.count(
            F.when(
                # If column is Double or Float, check both NaN and Null
                (F.isnan(c) | F.col(c).isNull()) if dtypes_dict[c] in ("double", "float")
                # For other types (Timestamp, String, Int), check only Null
                else F.col(c).isNull(), 
                c
            )
        ).alias(c)
        for c in dataframe.columns
    ])
    
    # 4. Transpose the result into a vertical table for better readability
    summary = null_counts.toPandas().transpose().rename(columns={0: 'missing_count'})

    # 5. Calculate the percentage of missing values
    summary['percentage'] = (summary['missing_count'] / total_rows) * 100
    
    return summary

# %%
# Check for missing values in the final 'geolocation_final_clean' dataset.
geolocation_missing_values = check_missing_values(geolocation_drop_duplicates)
print(geolocation_missing_values)
# Out:
# [Stage 72:>                                                         (0 + 2) / 2]
#                              missing_count  percentage
# geolocation_zip_code_prefix              0         0.0
# geolocation_lat                          0         0.0
# geolocation_lng                          0         0.0
# geolocation_city                         0         0.0
# geolocation_state                        0         0.0
# geolocation_city_clean                   0         0.0

# %% [markdown]
# 🧩 No missing values in the final geolocation dataset.

# %% [markdown]
# ### Dropping the dirty column

# %%
# Remove the original 'dirty' column to prevent redundancy and confusion.
# Promote the 'clean' version to the original column name.
geolocation_final_clean = geolocation_drop_duplicates.drop("geolocation_city") \
              .withColumnRenamed("geolocation_city_clean", "geolocation_city")

# %%
# Data is cleaned and ready for EDA

# 🎲 Selecting 100 unique examples for verification
geolocation_final_clean.orderBy(F.rand()).limit(100).toPandas()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                        72251       -15.787382       -48.123714
# 1                        08255       -23.552119       -46.427861
# 2                        35248       -18.982912       -41.217010
# 3                        36060       -21.734177       -43.328326
# 4                        92500       -30.120294       -51.329486
# 5                        39648       -17.091683       -42.538661
# 6                        30644       -19.995822       -44.006024
# 7                        89120       -26.838116       -49.248543
# 8                        03372       -23.570794       -46.556099
# 9                        27345       -22.544378       -44.184281
# 10                       87702       -23.076655       -52.454632
# 11                       38030       -19.768490       -47.929463
# 12                       06390       -23.537343       -46.847459
# 13                       14711       -20.945275       -48.465746
# 14                       87015       -23.425438       -51.961780
# 15                       28080       -21.741312       -41.324184
# 16                       35450       -20.247383       -43.804830
# 17                       38050       -19.765245       -47.953304
# 18                       50781        -8.085248       -34.936735
# 19                       02883       -23.437559       -46.714841
# 20                       02229       -23.480375       -46.567304
# 21                       69928       -10.332697       -67.186616
# 22                       86046       -23.353820       -51.152980
# 23                       33400       -19.624233       -43.903083
# 24                       38740       -18.945192       -46.982081
# 25                       95043       -29.144822       -51.175509
# 26                       95560       -29.395989       -49.768143
# 27                       88010       -27.596429       -48.552761
# 28                       45480       -13.228836       -39.503182
# 29                       08431       -23.533679       -46.423545
# 30                       28905       -22.883301       -42.028718
# 31                       46700       -12.653129       -42.217795
# 32                       56320        -9.372341       -40.493669
# 33                       35540       -20.695732       -44.826227
# 34                       95500       -29.825815       -50.525582
# 35                       86975       -23.543229       -51.675578
# 36                       03625       -23.515435       -46.510726
# 37                       41320       -12.900442       -38.440773
# 38                       27655       -22.284667       -43.917452
# 39                       71665       -15.833237       -47.832208
# 40                       89820       -26.879679       -52.375814
# 41                       77755        -7.981257       -48.963783
# 42                       85560       -25.853998       -52.527488
# 43                       11618       -23.788592       -45.623559
# 44                       24937       -22.963018       -43.015208
# 45                       08740       -23.547827       -46.206417
# 46                       25640       -22.520914       -43.181473
# 47                       37795       -22.071682       -46.575614
# 48                       79002       -20.462010       -54.621566
# 49                       78580        -9.878677       -56.086707
# 50                       06385       -23.548041       -46.842727
# 51                       39205       -18.226817       -45.242140
# 52                       83833       -25.648603       -49.314681
# 53                       05881       -23.684886       -46.779298
# 54                       13607       -22.376230       -47.354239
# 55                       87701       -23.088891       -52.467883
# 56                       16850       -21.170187       -51.042163
# 57                       13141       -22.801189       -47.131090
# 58                       69054        -3.078485       -59.991727
# 59                       13310       -23.272027       -47.309432
# 60                       03622       -23.520418       -46.520293
# 61                       25780       -22.167203       -42.939350
# 62                       28540       -22.024621       -42.360009
# 63                       07853       -23.323759       -46.714180
# 64                       11750       -24.301014       -46.979989
# 65                       01536       -23.564470       -46.622650
# 66                       89208       -26.337264       -48.831073
# 67                       21555       -22.853946       -43.364480
# 68                       04545       -23.596678       -46.678862
# 69                       27600       -22.245179       -43.701853
# 70                       74453       -16.657625       -49.333166
# 71                       74923       -16.769176       -49.236826
# 72                       60175        -3.741556       -38.476292
# 73                       89665       -27.342959       -51.611780
# 74                       04942       -23.696844       -46.777166
# 75                       85819       -24.976812       -53.454715
# 76                       15120       -20.838939       -49.630833
# 77                       13800       -22.437689       -46.954823
# 78                       93804       -29.635289       -51.024044
# 79                       88058       -27.452237       -48.411614
# 80                       63500        -6.352979       -39.296323
# 81                       84600       -26.207975       -51.022941
# 82                       72545       -16.011058       -47.997392
# 83                       09040       -23.659817       -46.535175
# 84                       89930       -26.457281       -53.499437
# 85                       04858       -23.769710       -46.717971
# 86                       92500       -30.112696       -51.365034
# 87                       06622       -23.543418       -46.899102
# 88                       72120       -15.801907       -48.061161
# 89                       03814       -23.489355       -46.484189
# 90                       93320       -29.688301       -51.132832
# 91                       92120       -29.952766       -51.170332
# 92                       28300       -21.209667       -41.895433
# 93                       26215       -22.750671       -43.442255
# 94                       20231       -22.913278       -43.186155
# 95                       14807       -21.806989       -48.156434
# 96                       69970        -8.167423       -70.764599
# 97                       88430       -27.474628       -49.631834
# 98                       03734       -23.508456       -46.524578
# 99                       50660        -8.060352       -34.938520
#
#    geolocation_state               geolocation_city
# 0                 df                       brasilia
# 1                 sp                      sao paulo
# 2                 mg                      goiabeira
# 3                 mg                   juiz de fora
# 4                 rs                         guaiba
# 5                 mg               chapada do norte
# 6                 mg                 belo horizonte
# 7                 sc                          timbo
# 8                 sp                      sao paulo
# 9                 rj                    barra mansa
# 10                pr                      paranavai
# 11                mg                        uberaba
# 12                sp                    carapicuiba
# 13                sp                      bebedouro
# 14                pr                        maringa
# 15                rj          campos dos goytacazes
# 16                mg                      itabirito
# 17                mg                        uberaba
# 18                pe                         recife
# 19                sp                      sao paulo
# 20                sp                      sao paulo
# 21                ac              placido de castro
# 22                pr                       londrina
# 23                mg                    lagoa santa
# 24                mg                     patrocinio
# 25                rs                  caxias do sul
# 26                rs                         torres
# 27                sc                  florianopolis
# 28                ba                        mutuipe
# 29                sp                      sao paulo
# 30                rj                      cabo frio
# 31                ba                       ibitiara
# 32                pe                      petrolina
# 33                mg                       oliveira
# 34                rs      santo antonio da patrulha
# 35                pr                     mandaguari
# 36                sp                      sao paulo
# 37                ba                       salvador
# 38                rj                  conservatoria
# 39                df                       brasilia
# 40                sc                        xanxere
# 41                to                 bernardo sayao
# 42                pr                    chopinzinho
# 43                sp                  sao sebastiao
# 44                rj                         marica
# 45                sp                mogi das cruzes
# 46                rj                     petropolis
# 47                mg                       andradas
# 48                ms                   campo grande
# 49                mt                  alta floresta
# 50                sp                    carapicuiba
# 51                mg                    tres marias
# 52                pr             fazenda rio grande
# 53                sp                      sao paulo
# 54                sp                         araras
# 55                pr                      paranavai
# 56                sp                        lavinia
# 57                sp                       paulinia
# 58                am                         manaus
# 59                sp                            itu
# 60                sp                      sao paulo
# 61                rj  sao jose do vale do rio preto
# 62                rj                       cordeiro
# 63                sp                franco da rocha
# 64                sp                        peruibe
# 65                sp                      sao paulo
# 66                sc                      joinville
# 67                rj                 rio de janeiro
# 68                sp                      sao paulo
# 69                rj                        valenca
# 70                go                        goiania
# 71                go           aparecida de goiania
# 72                ce                      fortaleza
# 73                sc                       capinzal
# 74                sp                      sao paulo
# 75                pr                       cascavel
# 76                sp                 neves paulista
# 77                sp                     mogi mirim
# 78                rs                      sapiranga
# 79                sc                  florianopolis
# 80                ce                         iguatu
# 81                pr               uniao da vitoria
# 82                df                       brasilia
# 83                sp                    santo andre
# 84                sc              sao jose do cedro
# 85                sp                      sao paulo
# 86                rs                         guaiba
# 87                sp                        jandira
# 88                df                       brasilia
# 89                sp                      sao paulo
# 90                rs                  novo hamburgo
# 91                rs                         canoas
# 92                rj                      itaperuna
# 93                rj                    nova iguacu
# 94                rj                 rio de janeiro
# 95                sp                     araraquara
# 96                ac                       tarauaca
# 97                sc                    petrolandia
# 98                sp                      sao paulo
# 99                pe                         recife

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being
# persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data
# Analysis (EDA) and reporting stages.

# %%
# Storing the refined geolocation dataset to the Silver Layer in Parquet format
geolocation_final_clean.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_geolocation.parquet")

# %% [markdown]
# # SELLERS

# %%
# --- Define Sellers Schema ---
# Zip_code is StringType to preserve leading zeros, essential for Brazilian CEPs(Postal Addressing Code).
sellers_schema = StructType([
    StructField("seller_id", StringType(), True),
    StructField("seller_zip_code_prefix", StringType(), True),
    StructField("seller_city", StringType(), True),
    StructField("seller_state", StringType(), True)
])

# --- Load Sellers Dataset ---
sellers = (spark.read.format("csv")
    .option("header", "true")
    .schema(sellers_schema)  
    .option("sep", ",")
    .option("quote", "\"")
    .option("escape", "\"")
    .option("encoding", "UTF-8")
    .option("multiLine", "true")
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_sellers_dataset.csv")
)

# %%
# Display schema
sellers.printSchema()
# Out:
# root
#  |-- seller_id: string (nullable = true)
#  |-- seller_zip_code_prefix: string (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- seller_state: string (nullable = true)

# %%
# Total number of records
sellers.count()
# Out:
# 3095

# %%
# Show first 5 rows
sellers.limit(5).toPandas()
# Out:
#                           seller_id seller_zip_code_prefix        seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                  13023           campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                  13844         mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                  20031     rio de janeiro
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                  04195          sao paulo
# 4  51a04a8a6bdcb23deccc82b0b80742cf                  12914  braganca paulista
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
# 3           SP
# 4           SP

# %% [markdown]
# ### Trim String Columns

# %%
# Cleans the sellers dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
sellers_nullified_trimmed = trim_and_nullify_strings(sellers)

# %% [markdown]
# ### Normalize Brazilian Characters

# %%
# Remove accents to ensure 'são paulo' and 'sao paulo' are treated as the same city
sellers_normalized_brazilian_characters = sellers_nullified_trimmed.withColumn(
    "seller_city_clean",
    strip_accents_udf(F.col("seller_city"))
)

# %%
# Validation: Check for city names that still contain special characters (not a-z or space)
# to verify if the normalization function was successful.
sellers_normalized_brazilian_characters.filter(F.col("seller_city").rlike(r"[^a-z\s]")) \
    .select("seller_city", "seller_city_clean", "seller_state") \
    .toPandas().head()
# Out:
#              seller_city      seller_city_clean seller_state
# 0             lages - sc             lages - sc           sc
# 1           auriflama/sp           auriflama/sp           sp
# 2  sao paulo / sao paulo  sao paulo / sao paulo           sp
# 3             são paulo              sao paulo           sp
# 4  santa barbara d´oeste  santa barbara d´oeste           sp

# %% [markdown]
# ### Handling Hyphenated City Entries

# %%
# Remove hyphens and multiple spaces
sellers_cleaned_spacing_and_hyphens = sellers_normalized_brazilian_characters.withColumn(
    "seller_city_clean", 
    clean_spacing_and_hyphens("seller_city_clean")  
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(sellers_cleaned_spacing_and_hyphens
    .filter(F.col("seller_city").like("%-%"))
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
).toPandas()
# Out:
#       seller_city seller_city_clean seller_state
# 0       andira-pr         andira pr           pr
# 1      lages - sc          lages sc           sc
# 2  sao paulo - sp      sao paulo sp           sp

# %% [markdown]
# ### Regional Naming Normalization

# %%
# Refines specific regional naming conventions by mapping variations like "d' oeste" 
# to a standardized format, ensuring consistent grouping across the 'seller_city_clean' column.
sellers_normalized_doeste_and_others = sellers_cleaned_spacing_and_hyphens.withColumn(
    "seller_city_clean", 
    normalize_doeste_and_others("seller_city_clean")
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.

# Define the pattern for specialized regional naming and characters
special_cities_pattern = "agua|alho|alianca|arco|abadia|ajuda|alcantara|avila|oeste|arca|anta"

# Filter for rows that match normalization criteria
(sellers_normalized_doeste_and_others
    .filter(F.col("seller_city").rlike(special_cities_pattern))
    .select("seller_city", "seller_city_clean")
    .distinct()
).toPandas()
# Out:
#                        seller_city              seller_city_clean
# 0                            garca                          garca
# 1               sao miguel d'oeste              sao miguel doeste
# 2                     rio do oeste                   rio do oeste
# 3                          jaragua                        jaragua
# 4   arraial d'ajuda (porto seguro)  arraial dajuda (porto seguro)
# 5            santa barbara d'oeste           santa barbara doeste
# 6                       cataguases                     cataguases
# 7                  abadia de goias                abadia de goias
# 8                        jaguaruna                      jaguaruna
# 9                santa cruz do sul              santa cruz do sul
# 10                  santa catarina                 santa catarina
# 11           santa barbara d´oeste           santa barbara doeste
# 12                 aguas claras df                aguas claras df
# 13           santa rosa de viterbo          santa rosa de viterbo
# 14             entre rios do oeste            entre rios do oeste
# 15                  jaragua do sul                 jaragua do sul
# 16             santana de parnaiba            santana de parnaiba
# 17           santa barbara d oeste           santa barbara doeste
# 18                         palhoca                        palhoca
# 19                     santa maria                    santa maria
# 20        santa terezinha de goias       santa terezinha de goias
# 21                        araguari                       araguari
# 22                      mandaguacu                     mandaguacu
# 23                      santa rosa                     santa rosa
# 24                      mandaguari                     mandaguari
# 25             vicente de carvalho            vicente de carvalho
# 26             sao miguel do oeste            sao miguel do oeste
# 27                feira de santana               feira de santana
# 28            santa maria da serra           santa maria da serra
# 29       santa terezinha de itaipu      santa terezinha de itaipu
# 30                      jaguariuna                     jaguariuna
# 31                     lagoa santa                    lagoa santa
# 32                formosa do oeste               formosa do oeste
# 33           santa rita do sapucai          santa rita do sapucai
# 34          vitoria de santo antao         vitoria de santo antao
# 35                   santa cecilia                  santa cecilia

# %% [markdown]
# ###  Removing Parentheses

# %%
# There are some rows where seller_city contains '(' or ')'

# Apply the 'remove_parentheses' function to normalize the city names
sellers_removed_parentheses = sellers_normalized_doeste_and_others\
    .withColumn("seller_city_clean", remove_parentheses("seller_city_clean"))

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(sellers_removed_parentheses\
    .filter(F.col("seller_city").contains("("))
    .select("seller_city", "seller_city_clean")
    .distinct()).toPandas()
# Out:
#                       seller_city seller_city_clean
# 0  arraial d'ajuda (porto seguro)    arraial dajuda

# %% [markdown]
# ### Cleaning Special Characters

# %%
# There are still special characters to fix
# Filters for city names containing special characters (not a-z or space)
sellers_removed_parentheses.filter(F.col("seller_city_clean").rlike(r"[^a-z\s]")) \
    .select("seller_city", "seller_city_clean").distinct() \
    .toPandas()
# Out:
#                                  seller_city  \
# 0                  vendas@creditparts.com.br
# 1                      sao paulo / sao paulo
# 2                             maua/sao paulo
# 3                    carapicuiba / sao paulo
# 4                       mogi das cruzes / sp
# 5                               auriflama/sp
# 6                                    sp / sp
# 7                        jacarei / sao paulo
# 8   novo hamburgo, rio grande do sul, brasil
# 9             rio de janeiro \rio de janeiro
# 10           rio de janeiro / rio de janeiro
# 11                     santo andre/sao paulo
# 12                                    sbc/sp
# 13                ribeirao preto / sao paulo
# 14                            cariacica / es
# 15                   barbacena/ minas gerais
# 16    rio de janeiro, rio de janeiro, brasil
# 17                 sao sebastiao da grama/sp
# 18                                  04482255
# 19                                pinhais/pr
#
#                            seller_city_clean
# 0                  vendas@creditparts.com.br
# 1                      sao paulo / sao paulo
# 2                             maua/sao paulo
# 3                    carapicuiba / sao paulo
# 4                       mogi das cruzes / sp
# 5                               auriflama/sp
# 6                                    sp / sp
# 7                        jacarei / sao paulo
# 8   novo hamburgo, rio grande do sul, brasil
# 9             rio de janeiro \rio de janeiro
# 10           rio de janeiro / rio de janeiro
# 11                     santo andre/sao paulo
# 12                                    sbc/sp
# 13                ribeirao preto / sao paulo
# 14                            cariacica / es
# 15                   barbacena/ minas gerais
# 16    rio de janeiro, rio de janeiro, brasil
# 17                 sao sebastiao da grama/sp
# 18                                  04482255
# 19                                pinhais/pr

# %%
# Split the city names 
sellers_split_city = sellers_removed_parentheses.withColumn(
    "seller_city_clean",
    F.trim(F.split(F.col("seller_city_clean"), r"/|\\|,").getItem(0))
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(sellers_split_city
    .filter(F.col("seller_city").rlike(r"[,/\\\\]"))
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
).toPandas()
# Out:
#                                  seller_city       seller_city_clean  \
# 0                       mogi das cruzes / sp         mogi das cruzes
# 1                             maua/sao paulo                    maua
# 2                                     sbc/sp                     sbc
# 3                      sao paulo / sao paulo               sao paulo
# 4                               auriflama/sp               auriflama
# 5   novo hamburgo, rio grande do sul, brasil           novo hamburgo
# 6             rio de janeiro \rio de janeiro          rio de janeiro
# 7                  sao sebastiao da grama/sp  sao sebastiao da grama
# 8                    barbacena/ minas gerais               barbacena
# 9     rio de janeiro, rio de janeiro, brasil          rio de janeiro
# 10           rio de janeiro / rio de janeiro          rio de janeiro
# 11                            cariacica / es               cariacica
# 12                   carapicuiba / sao paulo             carapicuiba
# 13                ribeirao preto / sao paulo          ribeirao preto
# 14                                   sp / sp                      sp
# 15                     santo andre/sao paulo             santo andre
# 16                       jacarei / sao paulo                 jacarei
# 17                                pinhais/pr                 pinhais
#
#    seller_state
# 0            sp
# 1            sp
# 2            sp
# 3            sp
# 4            sp
# 5            rs
# 6            rj
# 7            sp
# 8            mg
# 9            rj
# 10           rj
# 11           es
# 12           sp
# 13           sp
# 14           sp
# 15           sp
# 16           sp
# 17           pr

# %% [markdown]
# ### Identifying and Correcting State Codes in City Fields

# %%
# Identify rows where the city name is only 2 characters long (likely a state code)
(sellers_split_city
    .filter(F.length(F.col("seller_city")) < 3)
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
).toPandas()
# Out:
#   seller_city seller_city_clean seller_state
# 0          sp                sp           sp

# %%
# Replaces the state code "sp" with "sao paulo"
sellers_cities_fixed_state_codes = sellers_split_city.withColumn(
    "seller_city_clean",
    F.when(F.col("seller_city_clean") == "sp", "sao paulo")
     .otherwise(F.col("seller_city_clean"))
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(sellers_cities_fixed_state_codes
    .filter(F.length(F.col("seller_city")) < 3)
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
).toPandas()
# Out:
#   seller_city seller_city_clean seller_state
# 0          sp         sao paulo           sp

# %% [markdown]
# ### Normalizing Regional Suffixes

# %% [markdown]
# ✂️ This step merges variations of 'do oeste' and 'de alcantara' into a single unified format
# to prevent duplicate city entries (e.g., 'do oeste' to 'doeste').

# %%
# Standardize regional suffixes by merging multi-part names 
sellers_regional_suffixes = sellers_cities_fixed_state_codes.withColumn(
    "seller_city_clean",
    F.regexp_replace(F.col("seller_city_clean"), r"do\s+oeste", "doeste")
).withColumn(
    "seller_city_clean",
    F.regexp_replace(F.col("seller_city_clean"), r"de\s+alcantara", "dalcantara")
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(sellers_regional_suffixes
    .filter(F.col("seller_city").rlike("do oeste|de alcantara"))
    .select("seller_city", "seller_city_clean")
    .distinct()
).toPandas()
# Out:
#            seller_city  seller_city_clean
# 0  sao miguel do oeste  sao miguel doeste
# 1         rio do oeste         rio doeste
# 2  entre rios do oeste  entre rios doeste
# 3     formosa do oeste     formosa doeste

# %% [markdown]
# ### Removing Trailing State Abbreviations

# %% [markdown]
# ✂️ Some rows have a state abbreviation at the end of the line (e.g., 'franca sp'),
# while others have suffix characters that are not state codes, like 'santa fe'.

# %%
# Inspect rows where 'seller_city' contains a state code at the end of the string.
(sellers_regional_suffixes
    .filter(F.col("seller_city_clean").rlike(r"\s[a-z]{2}$"))
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
).toPandas()
# Out:
#          seller_city  seller_city_clean seller_state
# 0       sao paulo sp       sao paulo sp           sp
# 1  angra dos reis rj  angra dos reis rj           rj
# 2          andira-pr          andira pr           pr
# 3        brasilia df        brasilia df           df
# 4    aguas claras df    aguas claras df           sp
# 5         lages - sc           lages sc           sc
# 6     sao paulo - sp       sao paulo sp           sp

# %% [markdown]
# ⚠️ Instead of a general state code pattern that contains all state codes in Brazil, a dataset-specific regex was used to remove state suffixes. This prevents the accidental deletion of name-internal characters that mimic state codes, such as in the case of 'Santo Se'."

# %%
# This pattern only matches specific state codes at the end of the string
state_codes_pattern_sellers = r"\s(mg|sp|rj|pr|df|sc)$"

sellers_trailing_state_code = sellers_regional_suffixes.withColumn(
    "seller_city_clean",
    F.regexp_replace(F.col("seller_city_clean"), state_codes_pattern_sellers, "")
)

# %%
# Validation: Check unique examples of city names ending in state codes to ensure correct processing.
(sellers_trailing_state_code
    .filter(F.col("seller_city").rlike(r"\s[a-z]{2}$"))
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
).toPandas()
# Out:
#             seller_city seller_city_clean seller_state
# 0  mogi das cruzes / sp   mogi das cruzes           sp
# 1          sao paulo sp         sao paulo           sp
# 2       aguas claras df      aguas claras           sp
# 3     angra dos reis rj    angra dos reis           rj
# 4        cariacica / es         cariacica           es
# 5               sp / sp         sao paulo           sp
# 6            lages - sc             lages           sc
# 7        sao paulo - sp         sao paulo           sp
# 8           brasilia df          brasilia           df

# %% [markdown]
# **⚠️ Correction:** Manually fixing a state mismatch for **Águas Claras**. Even though the original data says 'sp', this city belongs to 'df'.

# %%
# Fixing state mismatch
sellers_trailing_state_code = sellers_trailing_state_code.withColumn(
    "seller_state",
    F.when(F.col("seller_city_clean") == "aguas claras", "df")
     .otherwise(F.col("seller_state"))
)

# %%
# Validation: Check unique examples of city names ending in state codes to ensure correct processing.
(sellers_trailing_state_code
    .filter(F.col("seller_city").rlike(r"\s[a-z]{2}$"))
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
).toPandas()
# Out:
#             seller_city seller_city_clean seller_state
# 0  mogi das cruzes / sp   mogi das cruzes           sp
# 1          sao paulo sp         sao paulo           sp
# 2       aguas claras df      aguas claras           df
# 3     angra dos reis rj    angra dos reis           rj
# 4        cariacica / es         cariacica           es
# 5               sp / sp         sao paulo           sp
# 6            lages - sc             lages           sc
# 7        sao paulo - sp         sao paulo           sp
# 8           brasilia df          brasilia           df

# %% [markdown]
# ### Manual Fixing Some Incorrect Data

# %%
# Manual data cleaning for the seller_city column:
# 's jose do rio preto' -> 'sao jose do rio preto', 
# 'sbc' -> 'sao bernardo do campo'
# 'vendas@creditparts.com.br' and '04482255'-> Replacing with the correct city name associated with their zip codes

# %%
# Validation: Check for city names that still contain special characters (not a-z or space)
# to verify if the normalization function was successful.
sellers_trailing_state_code.filter(F.col("seller_city_clean").rlike(r"[^a-z\s]")) \
    .select("seller_city", "seller_city_clean", "seller_state") \
    .toPandas()
# Out:
#                  seller_city          seller_city_clean seller_state
# 0                   04482255                   04482255           rj
# 1  vendas@creditparts.com.br  vendas@creditparts.com.br           pr

# %%
manual_fixes = {
    "s jose do rio preto": "sao jose do rio preto",
    "sbc": "sao bernardo do campo",
    "vendas@creditparts.com.br": "maringa", # Replace with the actual city name for that zip
    "04482255": "rio de janeiro", # Replace with the actual city name for that zip
    "ao bernardo do campo" : "sao bernardo do campo",
    "scao jose do rio pardo" : "sao jose do rio pardo"
}
sellers_manual_fix = sellers_trailing_state_code.replace(manual_fixes, subset=["seller_city_clean"])

# %%
# Validation: Check for city names that still contain special characters (not a-z or space)
# to verify if the normalization function was successful.
sellers_manual_fix.filter(F.col("seller_city_clean").rlike(r"[^a-z\s]")) \
    .select("seller_city", "seller_city_clean", "seller_state") \
    .toPandas()
# Out:
# Empty DataFrame
# Columns: [seller_city, seller_city_clean, seller_state]
# Index: []

# %% [markdown]
# ### 🕵️  Final validation: Reviewing rows to ensure all cleaning transformations were applied correctly.

# %%
# 🎲 Random Sampling: Selecting 100 unique examples for manual verification
(sellers_manual_fix
    .filter(F.col("seller_city").rlike(r"[^a-z\s]"))
    .select("seller_city", "seller_city_clean", "seller_state")
    .distinct()
    .orderBy(F.rand()) # This shuffles the rows randomly
    .limit(100)        # This picks the first 100 from the shuffle
    .toPandas()
)
# Out:
#                                  seller_city       seller_city_clean  \
# 0                             cariacica / es               cariacica
# 1                             maua/sao paulo                    maua
# 2                                    sp / sp               sao paulo
# 3                      santo andre/sao paulo             santo andre
# 4                                 são paulo               sao paulo
# 5                    carapicuiba / sao paulo             carapicuiba
# 6                  vendas@creditparts.com.br                 maringa
# 7                      sao paulo / sao paulo               sao paulo
# 8                                     sbc/sp   sao bernardo do campo
# 9                                  andira-pr                  andira
# 10                       jacarei / sao paulo                 jacarei
# 11                   barbacena/ minas gerais               barbacena
# 12                      mogi das cruzes / sp         mogi das cruzes
# 13                            sao paulo - sp               sao paulo
# 14                                pinhais/pr                 pinhais
# 15                ribeirao preto / sao paulo          ribeirao preto
# 16            rio de janeiro \rio de janeiro          rio de janeiro
# 17                              auriflama/sp               auriflama
# 18  novo hamburgo, rio grande do sul, brasil           novo hamburgo
# 19                                  04482255          rio de janeiro
# 20                 sao sebastiao da grama/sp  sao sebastiao da grama
# 21    rio de janeiro, rio de janeiro, brasil          rio de janeiro
# 22                                lages - sc                   lages
# 23           rio de janeiro / rio de janeiro          rio de janeiro
# 24                        sao miguel d'oeste       sao miguel doeste
# 25            arraial d'ajuda (porto seguro)          arraial dajuda
# 26                     santa barbara d'oeste    santa barbara doeste
# 27                     santa barbara d´oeste    santa barbara doeste
#
#    seller_state
# 0            es
# 1            sp
# 2            sp
# 3            sp
# 4            sp
# 5            sp
# 6            pr
# 7            sp
# 8            sp
# 9            pr
# 10           sp
# 11           mg
# 12           sp
# 13           sp
# 14           pr
# 15           sp
# 16           rj
# 17           sp
# 18           rs
# 19           rj
# 20           sp
# 21           rj
# 22           sc
# 23           rj
# 24           sc
# 25           ba
# 26           sp
# 27           sp

# %% [markdown]
# ### Removing Duplicates

# %%
# Final cleanup: Trimming whitespace and converting empty strings to Null.
sellers_final_trim = trim_and_nullify_strings(sellers_manual_fix)

# %%
# Check for duplicates
check_duplicates(sellers_final_trim)
# Out:
# ✅ No exact duplicate rows found. Every row is unique.

# %% [markdown]
# ✅ No exact duplicate rows found. Every row is unique.

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values in the final 'sellers_final_clean' dataset.
sellers_missing_values = check_missing_values(sellers_final_trim)
print(sellers_missing_values)
# Out:
#                         missing_count  percentage
# seller_id                           0         0.0
# seller_zip_code_prefix              0         0.0
# seller_city                         0         0.0
# seller_state                        0         0.0
# seller_city_clean                   0         0.0

# %% [markdown]
# 🧩 No missing values in the final sellers dataset.

# %% [markdown]
# ### Dropping the Dirty Column

# %%
# Step 1: Remove the original unrefined 'seller_city' column to prevent redundancy.
# Step 2: Promote the 'seller_city_clean' version to the original column name.
# Verified: The dataset is free of duplicate records and ready for the Silver Layer. ✅
sellers_final_clean = sellers_final_trim.drop("seller_city") \
    .withColumnRenamed("seller_city_clean", "seller_city")

# %%
# 🎲 Selecting 100 unique examples for verification and quality check.
sellers_final_clean.orderBy(F.rand()).limit(100).toPandas()
# Out:
#                            seller_id seller_zip_code_prefix seller_state  \
# 0   f1198c871e0171278b63f40d112caeec                  01220           sp
# 1   3afc536624bc2e65bddfb5db33cc01f3                  30150           mg
# 2   fe87f472055fbcf1d7e691c00b1560dc                  13085           sp
# 3   c97aa4ee7420f937da13b7f9e2228b99                  93510           rs
# 4   d9e8c084b68fe958861d8f2c21202e6b                  05528           sp
# 5   60562ab00b8054280520d390c8c0045c                  04809           sp
# 6   95f83f51203c626648c875dd41874c7f                  37564           mg
# 7   15aac934c58d886785ac1b17953ea898                  29480           es
# 8   62760d278921b5f352461620d68a9cee                  13320           sp
# 9   daeb5653dd96c1b11860f72209795012                  31310           mg
# 10  5f2684dab12e59f83bef73ae57724e45                  05125           sp
# 11  d9cd369bffa979d1634f8e1318bf2f1b                  15115           sp
# 12  e4253cef933647000a82ff39c67b7bde                  05856           sp
# 13  1710c3aaa9c6b44ec3883ee0fe300e21                  09551           sp
# 14  05d2173d43ea568aa0540eba70d2ca76                  37135           mg
# 15  a7dc4098e4da6e41b426269d12ae7e91                  04386           sp
# 16  6ee85be3693ed79a8e80718743d80655                  03937           sp
# 17  ae8bfdbf1c2a2a2dee92d799db0a31c6                  85900           pr
# 18  7dc8c42cc750eeafea6c85712ffee9bf                  05424           sp
# 19  d79e8478eed9999493990b44955fb22e                  20081           rj
# 20  50c9975695009e5e6473912e83a6d1da                  35530           mg
# 21  630008e0f062605a415d694489f6f82e                  01026           sp
# 22  4559697a8f7e637227c2eeaed843baff                  19029           sp
# 23  a1043bafd471dff536d0c462352beb48                  37175           mg
# 24  19484c79cef6c062cb177aa4ef2fcc3c                  13275           sp
# 25  f680f85bee2d253556ac91be391d2c82                  06365           sp
# 26  2d42ebcda99fd55f6f4bc2f1ca035d50                  76400           go
# 27  cc63f0dd2acba93ffed4fe9f8e0321fa                  15025           sp
# 28  4e0d109ccfba9a1151c103049880c857                  25550           rj
# 29  830379336fad8c6f3b15a4a3ddb5c66e                  02518           sp
# 30  e882b2a25a10b9c057cc49695f222c19                  25963           rj
# 31  13dd308f81fea30cc670c656b2b46cc3                  13454           sp
# 32  b274baf5bbd142410eb2958cf685d684                  95780           rs
# 33  a3e9a2c700480d9bb01fba070ba80a0e                  14940           sp
# 34  d4f117125b59ce73c3302f88ee40c458                  04058           sp
# 35  c33a5c3c983090c8b78a28e65052a20d                  88802           sc
# 36  8fe8786ee000001ab51d030dfd4a7bf1                  88490           sc
# 37  b3b17aab11f273023a5f22ca52e1eb70                  86065           pr
# 38  c611f4ce9ce875bcc063fa97fd4d7d12                  12944           sp
# 39  f1ed6bd0a9b11b581f16c851c6a5a527                  90240           rs
# 40  fa18c782a4866d313cadab567097f8f1                  31535           mg
# 41  d197aa8fbc64087f61984deef05f6227                  12224           sp
# 42  5b2e94f2c22b39ccc24d34ad0f669672                  01214           sp
# 43  9198786624eaeb375793215cad26cfa6                  89136           sc
# 44  6c6e3d67f969468f3bfd33f827a31222                  87035           pr
# 45  eeb6de78f79159600292e314a77cbd18                  88501           sc
# 46  818d28f936e791926d33bcb6ee94ef79                  04141           sp
# 47  a20d8058c866dbaeca014d2cd20ac62e                  12209           sp
# 48  72bc2cce903c872fe376a8faaa81d237                  04693           sp
# 49  aac29b1b99776be73c3049939652091d                  38408           mg
# 50  48436dade18ac8b2bce089ec2a041202                  27277           sp
# 51  9fc70243fb26800cba56e8f014797004                  30270           mg
# 52  74a9b9bddf14ece02beb81f52c41a88d                  01156           sp
# 53  0b90b6df587eb83608a64ea8b390cf07                  87025           pr
# 54  4917cee8d902e13428c3ec4b1ca6f315                  89031           sc
# 55  02ecc2a19303f05e59ce133fd923fff7                  09121           sp
# 56  88ef59b51bdaa941d10a853429f2b6ce                  83280           pr
# 57  dace965ca58120f92f8d742a9fa1864b                  14015           sp
# 58  a3dd39f583bc80bd8c5901c95878921e                  41342           ba
# 59  671585f5a2af58b6e276bc01003c0d2b                  80510           pr
# 60  cc3d14116804f7209f3884f6367f1152                  82940           pr
# 61  262237171f48e85819065498cac80d7b                  88352           sc
# 62  a066df7361163e7ddc5d7452dd17448b                  14401           sp
# 63  45213867cefbf2cd4c6177e10216a951                  13603           sp
# 64  ccc4bbb5f32a6ab2b7066a4130f114e3                  80310           pr
# 65  e7d5b006eb624f13074497221eb37807                  09291           sp
# 66  f918546be4bec7104d117789ba758b2b                  05634           sp
# 67  578fa3a9cb6b6dceab39231ad59cdaca                  60025           ce
# 68  f3511c85f59f8dec53d140501ee8e7a8                  80045           pr
# 69  eaaa46e98c9e61f6764dd1d7a2ab8b3e                  59775           rn
# 70  f25e239052084705e17a982bc600ab2a                  01123           sp
# 71  4be9ae93c4fc0f41713d71a4194ee1b3                  35500           mg
# 72  5741dc2bf5044c34d0698681c5081bed                  12226           sp
# 73  d20b021d3efdf267a402c402a48ea64b                  14940           sp
# 74  bc47d5d1490df2b36add65d733eafaba                  09163           sp
# 75  52092ddbd3a58c450a4459bf051b2287                  17300           sp
# 76  657969cca82e884d272385ec0ef06edd                  93608           rs
# 77  a247197e2e9c19a6a53a6888cb8b660f                  15056           sp
# 78  4b5f66b7adcf57f1ecc0d3c07dd6b177                  87025           pr
# 79  33cbbec1e7e1044aaf11d152172c776f                  95705           rs
# 80  2bf6a2c1e71bbd29a4ad64e6d3c3629f                  28615           rj
# 81  67883baaae6134ee81b271a542613728                  01310           sp
# 82  02c988090b766852e088c69d7fb3b551                  13473           sp
# 83  81783131d2a97c8d44d406a4be81b5d9                  18015           sp
# 84  ef506c96320abeedfb894c34db06f478                  03569           sp
# 85  87142160b41353c4e5fca2360caf6f92                  90230           rs
# 86  5f5b43b2bffa8656e4bc6efeb13cc649                  04880           sp
# 87  ed9eef5be0992d413d251fadba1a410d                  13845           sp
# 88  397c4d0c005b6f41f90098ac724e28cb                  09182           sp
# 89  817f85dbb65aa3e70831d90fe75cdf89                  18530           sp
# 90  056b4ada5bbc2c50cc7842547dda6b51                  26379           rj
# 91  13074f016982ff2bd6c58ced8682f000                  95705           rs
# 92  3985a3c45be355a4c57fde108bfabd1c                  95690           rs
# 93  499ec63c58e51296c9cf57edcfe1c8a8                  02918           sp
# 94  1992f8fb6b19fcccd97ca819811e7267                  01403           sp
# 95  17f51e7198701186712e53a39c564617                  03908           sp
# 96  916c9de0b5ad957346eeeb12f332687e                  80240           pr
# 97  4bfc7a4a1cf8d4d2121c27422d9e50b5                  03111           sp
# 98  79ebd9a61bac3eaf882805ed4ecfa12a                  85802           pr
# 99  e81e1f9c3e762e620f3fb60a51499e16                  89520           sc
#
#               seller_city
# 0               sao paulo
# 1          belo horizonte
# 2                campinas
# 3           novo hamburgo
# 4               sao paulo
# 5               sao paulo
# 6           borda da mata
# 7                   muqui
# 8                   salto
# 9          belo horizonte
# 10              sao paulo
# 11           bady bassitt
# 12              sao paulo
# 13     sao caetano do sul
# 14                alfenas
# 15              sao paulo
# 16              sao paulo
# 17                 toledo
# 18              sao paulo
# 19         rio de janeiro
# 20                claudio
# 21              sao paulo
# 22    presidente prudente
# 23               ilicinea
# 24               valinhos
# 25            carapicuiba
# 26                 uruacu
# 27  sao jose do rio preto
# 28     sao joao de meriti
# 29              sao paulo
# 30            teresopolis
# 31   santa barbara doeste
# 32             montenegro
# 33               ibitinga
# 34              sao paulo
# 35               criciuma
# 36            paulo lopes
# 37               londrina
# 38                atibaia
# 39           porto alegre
# 40         belo horizonte
# 41    sao jose dos campos
# 42              sao paulo
# 43                 rodeio
# 44                maringa
# 45                  lages
# 46              sao paulo
# 47    sao jose dos campos
# 48              sao paulo
# 49             uberlandia
# 50          volta redonda
# 51         belo horizonte
# 52              sao paulo
# 53                maringa
# 54               blumenau
# 55            santo andre
# 56              guaratuba
# 57              sao paulo
# 58               salvador
# 59               curitiba
# 60               curitiba
# 61                brusque
# 62                 franca
# 63                 araras
# 64               curitiba
# 65            santo andre
# 66              sao paulo
# 67              fortaleza
# 68               curitiba
# 69        messias targino
# 70              sao paulo
# 71            divinopolis
# 72    sao jose dos campos
# 73               ibitinga
# 74            santo andre
# 75          dois corregos
# 76         estancia velha
# 77  sao jose do rio preto
# 78                maringa
# 79        bento goncalves
# 80          nova friburgo
# 81              sao paulo
# 82              americana
# 83               sorocaba
# 84              sao paulo
# 85           porto alegre
# 86              sao paulo
# 87             mogi guacu
# 88            santo andre
# 89                  tiete
# 90              queimados
# 91        bento goncalves
# 92                rolante
# 93              sao paulo
# 94              sao paulo
# 95              sao paulo
# 96               curitiba
# 97              sao paulo
# 98               cascavel
# 99            curitibanos

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being
# persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data Analysis (EDA) and reporting stages.

# %%
# Storing the refined sellers dataset to the Silver Layer in Parquet format
sellers_final_clean.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_sellers.parquet")

# %% [markdown]
# # CUSTOMERS

# %%
# --- Define Customers Schema ---
# Zip_code is StringType to preserve leading zeros, essential for Brazilian CEPs(Postal Addressing Code).
customers_schema = StructType([
    StructField("customer_id", StringType(), True),
     StructField("customer_unique_id", StringType(), True),
    StructField("customer_zip_code_prefix", StringType(), True),
    StructField("customer_city", StringType(), True),
    StructField("customer_state", StringType(), True)
])

# Load the dataset using the manual schema
customers = (spark.read.format("csv")
    .option("header", "true")
    .schema(customers_schema)  
    .option("sep", ",")
    .option("quote", "\"")
    .option("escape", "\"")
    .option("encoding", "UTF-8")
    .option("multiLine", "true")
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_customers_dataset.csv")
)

# %%
# Display schema
customers.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %% [markdown]
# 🆔 **customer_id:** A unique key for each order placed. Changes with every new purchase.
# 👤 **customer_unique_id:** A unique identifier for the actual person.Remains the same across multiple orders.

# %%
# Show first 5 rows
customers.limit(5).toPandas()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_zip_code_prefix          customer_city customer_state
# 0                    14409                 franca             SP
# 1                    09790  sao bernardo do campo             SP
# 2                    01151              sao paulo             SP
# 3                    08775        mogi das cruzes             SP
# 4                    13056               campinas             SP

# %%
# Total number of records of the customers dataset
customers.count()
# Out:
# 99441

# %% [markdown]
# ### Trim String Columns

# %%
# Cleans the customers dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
customers_nullified_trimmed = trim_and_nullify_strings(customers)

# %%
# Inspection: Check for city names that contain special characters (not a-z or space)
customers_nullified_trimmed.filter(F.col("customer_city").rlike(r"[^a-z\s]")) \
    .select("customer_city").distinct() \
    .toPandas()
# Out:
#                  customer_city
# 0                 igarape-miri
# 1           machadinho d'oeste
# 2            sao jorge d'oeste
# 3       olho d'agua das cunhas
# 4                  entre-ijuis
# 5        santa barbara d'oeste
# 6             alvorada d'oeste
# 7   governador dix-sept rosado
# 8                    varre-sai
# 9                   pau d'arco
# 10                dias d'avila
# 11                  mogi-mirim
# 12       alta floresta d'oeste
# 13                   ji-parana
# 14       rancho alegre d'oeste
# 15        bandeirantes d'oeste
# 16                  guarda-mor
# 17              biritiba-mirim
# 18               sapucai-mirim
# 19              perola d'oeste
# 20                lagoa d'anta
# 21             estrela d'oeste
# 22                    tome-acu
# 23             arraial d'ajuda
# 24    nova brasilandia d'oeste
# 25                 xique-xique
# 26          santa rita d'oeste
# 27                   xangri-la
# 28            diamante d'oeste
# 29      quilometro 14 do mutum
# 30                olhos d'agua
# 31                  cipo-guacu
# 32               tanque d'arca
# 33                nao-me-toque
# 34       figueiropolis d'oeste
# 35               pariquera-acu
# 36                  mogi-guacu
# 37              herval d'oeste
# 38           itapejara d'oeste
# 39               guajara-mirim
# 40           aparecida d'oeste
# 41           conquista d'oeste
# 42         santa clara d'oeste
# 43                 ceara-mirim
# 44                 igarape-acu
# 45                pingo-d'agua
# 46                  embu-guacu
# 47            mirassol d'oeste
# 48          sao joao d'alianca
# 49      olho d'agua das flores
# 50          itaporanga d'ajuda
# 51            palmeira d'oeste
# 52                  mae d'agua

# %% [markdown]
# ### Normalize Brazilian Characters

# %%
# Remove accents to ensure 'são paulo' and 'sao paulo' are treated as the same city
customers_normalized_brazilian_characters = customers_nullified_trimmed.withColumn(
    "customer_city_clean",
    strip_accents_udf(F.col("customer_city"))
)

# %%
# Validation: Check for city names that still contain special characters (not a-z or space)
# to verify if the normalization function was successful.
customers_normalized_brazilian_characters.filter(F.col("customer_city").rlike(r"[^a-z\s]")) \
    .select("customer_city", "customer_city_clean", "customer_state").distinct() \
    .toPandas().head(50)
# Out:
#                  customer_city         customer_city_clean customer_state
# 0             diamante d'oeste            diamante d'oeste             pr
# 1                   mae d'agua                  mae d'agua             pb
# 2             mirassol d'oeste            mirassol d'oeste             mt
# 3                 pingo-d'agua                pingo-d'agua             mg
# 4        figueiropolis d'oeste       figueiropolis d'oeste             mt
# 5     nova brasilandia d'oeste    nova brasilandia d'oeste             ro
# 6                 nao-me-toque                nao-me-toque             rs
# 7                   guarda-mor                  guarda-mor             mg
# 8           santa rita d'oeste          santa rita d'oeste             sp
# 9        alta floresta d'oeste       alta floresta d'oeste             ro
# 10             arraial d'ajuda             arraial d'ajuda             ba
# 11                 ceara-mirim                 ceara-mirim             rn
# 12          machadinho d'oeste          machadinho d'oeste             ro
# 13                  pau d'arco                  pau d'arco             pa
# 14      olho d'agua das cunhas      olho d'agua das cunhas             ma
# 15          sao joao d'alianca          sao joao d'alianca             go
# 16                   xangri-la                   xangri-la             rs
# 17                  mogi-mirim                  mogi-mirim             sp
# 18             estrela d'oeste             estrela d'oeste             sp
# 19              biritiba-mirim              biritiba-mirim             sp
# 20        bandeirantes d'oeste        bandeirantes d'oeste             sp
# 21               sapucai-mirim               sapucai-mirim             mg
# 22                  embu-guacu                  embu-guacu             sp
# 23               guajara-mirim               guajara-mirim             ro
# 24               tanque d'arca               tanque d'arca             al
# 25  governador dix-sept rosado  governador dix-sept rosado             rn
# 26                  cipo-guacu                  cipo-guacu             sp
# 27                 xique-xique                 xique-xique             ba
# 28      quilometro 14 do mutum      quilometro 14 do mutum             es
# 29                lagoa d'anta                lagoa d'anta             rn
# 30                olhos d'agua                olhos d'agua             mg
# 31               pariquera-acu               pariquera-acu             sp
# 32                 entre-ijuis                 entre-ijuis             rs
# 33           aparecida d'oeste           aparecida d'oeste             sp
# 34              herval d'oeste              herval d'oeste             sc
# 35              perola d'oeste              perola d'oeste             pr
# 36                  mogi-guacu                  mogi-guacu             sp
# 37       rancho alegre d'oeste       rancho alegre d'oeste             pr
# 38          itaporanga d'ajuda          itaporanga d'ajuda             se
# 39                   ji-parana                   ji-parana             ro
# 40                    tome-acu                    tome-acu             pa
# 41                   varre-sai                   varre-sai             rj
# 42      olho d'agua das flores      olho d'agua das flores             al
# 43           conquista d'oeste           conquista d'oeste             mt
# 44           itapejara d'oeste           itapejara d'oeste             pr
# 45       santa barbara d'oeste       santa barbara d'oeste             sp
# 46                igarape-miri                igarape-miri             pa
# 47                 igarape-acu                 igarape-acu             pa
# 48           sao jorge d'oeste           sao jorge d'oeste             pr
# 49         santa clara d'oeste         santa clara d'oeste             sp

# %% [markdown]
# ### Handling Hyphenated City Entries

# %%
# Remove hyphens and multiple spaces
customers_cleaned_spacing_and_hyphens = customers_normalized_brazilian_characters.withColumn(
    "customer_city_clean", 
    clean_spacing_and_hyphens("customer_city_clean")   
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(customers_cleaned_spacing_and_hyphens
    .filter(F.col("customer_city").like("%-%"))
    .select("customer_city", "customer_city_clean", "customer_state")
    .distinct()
).toPandas()
# Out:
#                  customer_city         customer_city_clean customer_state
# 0                guajara-mirim               guajara mirim             ro
# 1                sapucai-mirim               sapucai mirim             mg
# 2                   embu-guacu                  embu guacu             sp
# 3                     tome-acu                    tome acu             pa
# 4                  ceara-mirim                 ceara mirim             rn
# 5                   guarda-mor                  guarda mor             mg
# 6                  igarape-acu                 igarape acu             pa
# 7                   mogi-guacu                  mogi guacu             sp
# 8   governador dix-sept rosado  governador dix sept rosado             rn
# 9                   cipo-guacu                  cipo guacu             sp
# 10                   xangri-la                   xangri la             rs
# 11              biritiba-mirim              biritiba mirim             sp
# 12                 xique-xique                 xique xique             ba
# 13                  mogi-mirim                  mogi mirim             sp
# 14                   varre-sai                   varre sai             rj
# 15                igarape-miri                igarape miri             pa
# 16                nao-me-toque                nao me toque             rs
# 17                   ji-parana                   ji parana             ro
# 18                 entre-ijuis                 entre ijuis             rs
# 19                pingo-d'agua                pingo d'agua             mg
# 20               pariquera-acu               pariquera acu             sp

# %% [markdown]
# ### Regional Naming Normalization

# %%
# Refines specific regional naming conventions by mapping variations like "d' oeste" 
# to a standardized format, ensuring consistent grouping across the 'customer_city_clean' column.
customers_normalized_doeste_and_others = customers_cleaned_spacing_and_hyphens.withColumn(
    "customer_city_clean", 
    normalize_doeste_and_others("customer_city_clean")
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.

# Define the pattern for specialized regional naming and characters
special_cities_pattern = "agua|alho|alianca|arco|abadia|ajuda|alcantara|avila|oeste|arca|anta"

# Filter for rows that match normalization criteria
(customers_normalized_doeste_and_others
    .filter(F.col("customer_city").rlike(special_cities_pattern))
    .select("customer_city", "customer_city_clean")
    .distinct()
).toPandas().head(50)
# Out:
#                customer_city       customer_city_clean
# 0                   ouroeste                  ouroeste
# 1       floresta do araguaia      floresta do araguaia
# 2                  paraguacu                 paraguacu
# 3               olhos d'agua               olhos dagua
# 4    central de santa helena   central de santa helena
# 5          paraiso das aguas         paraiso das aguas
# 6                      garca                     garca
# 7       santa rita do itueto      santa rita do itueto
# 8          santa fe de goias         santa fe de goias
# 9         vera cruz do oeste        vera cruz do oeste
# 10                   santana                   santana
# 11          alvorada d'oeste           alvorada doeste
# 12    santa cecilia do pavao    santa cecilia do pavao
# 13        sao joao d'alianca         sao joao dalianca
# 14         santana do serido         santana do serido
# 15                agua santa                agua santa
# 16             corrego danta             corrego danta
# 17                 arcoverde                 arcoverde
# 18       barra de santa rosa       barra de santa rosa
# 19         guaranta do norte         guaranta do norte
# 20       santa cruz de goias       santa cruz de goias
# 21     santa cruz de salinas     santa cruz de salinas
# 22               santa lucia               santa lucia
# 23              rio do oeste              rio do oeste
# 24              dias d avila               dias davila
# 25                agua preta                agua preta
# 26                   jaguari                   jaguari
# 27                  itaguara                  itaguara
# 28         colorado do oeste         colorado do oeste
# 29             carvalhopolis             carvalhopolis
# 30       formoso do araguaia       formoso do araguaia
# 31                 barcarena                 barcarena
# 32          limeira do oeste          limeira do oeste
# 33   santa cruz do rio pardo   santa cruz do rio pardo
# 34                 agua doce                 agua doce
# 35            ipora do oeste            ipora do oeste
# 36         itaguacu da bahia         itaguacu da bahia
# 37  santa cruz das palmeiras  santa cruz das palmeiras
# 38                 jaraguari                 jaraguari
# 39                      anta                      anta
# 40           aguas vermelhas           aguas vermelhas
# 41            morro da garca            morro da garca
# 42        santana do deserto        santana do deserto
# 43           santa albertina           santa albertina
# 44     rancho alegre d'oeste      rancho alegre doeste
# 45            santa mercedes            santa mercedes
# 46    sao geraldo do baguari    sao geraldo do baguari
# 47         santana do cariri         santana do cariri
# 48      santana da boa vista      santana da boa vista
# 49         capela de santana         capela de santana

# %%
# Chech for special characters to fix
# Filters for city names containing special characters (not a-z or space)
customers_normalized_doeste_and_others.filter(F.col("customer_city_clean").rlike(r"[^a-z\s]")) \
    .select("customer_city", "customer_city_clean").distinct() \
    .toPandas()
# Out:
#             customer_city     customer_city_clean
# 0  quilometro 14 do mutum  quilometro 14 do mutum

# %% [markdown]
# 🧹 Successfully removed special characters from all entries

# %% [markdown]
# ### Identifying and Correcting State Codes in City Fields

# %%
# Identify rows where the city name is only 2 characters long (likely a state code)
customer_2letter_city = (customers_normalized_doeste_and_others
    .filter(F.length(F.col("customer_city")) < 3)
    .select("customer_city", "customer_city_clean", "customer_state")
    .distinct()
)

# Display the results to verify which cities need fixing
customer_2letter_city.toPandas()
# Out:
# Empty DataFrame
# Columns: [customer_city, customer_city_clean, customer_state]
# Index: []

# %% [markdown]
# 🧹 There are no cities consisting solely of state codes.

# %% [markdown]
# ### Normalizing Regional Suffixes

# %%
# Standardize regional suffixes by merging multi-part names 
customers_regional_suffixes = customers_normalized_doeste_and_others.withColumn(
    "customer_city_clean",
    F.regexp_replace(F.col("customer_city_clean"), r"do\s+oeste", "doeste")
).withColumn(
    "customer_city_clean",
    F.regexp_replace(F.col("customer_city_clean"), r"de\s+alcantara", "dalcantara")
)

# %%
# Validation: Check for city names to verify if the normalization function was successful.
(customers_regional_suffixes
    .filter(F.col("customer_city").rlike("do oeste|de alcantara"))
    .select("customer_city", "customer_city_clean")
    .distinct()
).toPandas().head(50)
# Out:
#              customer_city   customer_city_clean
# 0        cruzeiro do oeste       cruzeiro doeste
# 1       sao jorge do oeste      sao jorge doeste
# 2      ouro preto do oeste     ouro preto doeste
# 3       vera cruz do oeste      vera cruz doeste
# 4         limeira do oeste        limeira doeste
# 5      sao miguel do oeste     sao miguel doeste
# 6      luizlandia do oeste     luizlandia doeste
# 7   sao pedro de alcantara  sao pedro dalcantara
# 8    sao lourenco do oeste   sao lourenco doeste
# 9             rio do oeste            rio doeste
# 10          ipora do oeste          ipora doeste
# 11   santa izabel do oeste   santa izabel doeste
# 12   santa tereza do oeste   santa tereza doeste
# 13     entre rios do oeste     entre rios doeste
# 14          uniao do oeste          uniao doeste
# 15        espigao do oeste        espigao doeste
# 16       colorado do oeste       colorado doeste
# 17        formosa do oeste        formosa doeste
# 18    sao gabriel do oeste    sao gabriel doeste
# 19     ouro verde do oeste     ouro verde doeste

# %% [markdown]
# ### Removing Trailing State Abbreviations

# %%
# Identify rows where the city names that end with a space followed by exactly two letters.
(customers_regional_suffixes
    .filter(F.col("customer_city").rlike(r"\s[a-z]{2}$"))
    .select("customer_city", "customer_city_clean", "customer_state")
    .distinct()
).toPandas()
# Out:
#         customer_city customer_city_clean customer_state
# 0         maria da fe         maria da fe             mg
# 1     coronel joao sa     coronel joao sa             ba
# 2         holambra ii         holambra ii             sp
# 3            sento se            sento se             ba
# 4        francisco sa        francisco sa             mg
# 5            pedro ii            pedro ii             pi
# 6              pio ix              pio ix             pi
# 7            santa fe            santa fe             pr
# 8  bonito de santa fe  bonito de santa fe             pb

# %%
🧹 There are no city names that contain trailing state codes.

# %% [markdown]
# ### 🕵️  Final validation: Reviewing rows to ensure all cleaning transformations were applied correctly.

# %%
# 🎲 Selecting 100 random examples for verification
(customers_regional_suffixes
    .filter(F.col("customer_city").rlike(r"[^a-z\s]"))
    .select("customer_city", "customer_city_clean")
    .distinct()
    .orderBy(F.rand()) # This shuffles the rows randomly
    .limit(100)        # This picks the first 100 from the shuffle
    .toPandas()
)
# Out:
#                  customer_city         customer_city_clean
# 0          santa clara d'oeste          santa clara doeste
# 1                  ceara-mirim                 ceara mirim
# 2     nova brasilandia d'oeste     nova brasilandia doeste
# 3                 lagoa d'anta                 lagoa danta
# 4                     tome-acu                    tome acu
# 5                   pau d'arco                   pau darco
# 6                   embu-guacu                  embu guacu
# 7              arraial d'ajuda              arraial dajuda
# 8           machadinho d'oeste           machadinho doeste
# 9               perola d'oeste               perola doeste
# 10          santa rita d'oeste           santa rita doeste
# 11            mirassol d'oeste             mirassol doeste
# 12                nao-me-toque                nao me toque
# 13       santa barbara d'oeste        santa barbara doeste
# 14               guajara-mirim               guajara mirim
# 15               tanque d'arca                tanque darca
# 16      quilometro 14 do mutum      quilometro 14 do mutum
# 17        bandeirantes d'oeste         bandeirantes doeste
# 18                 xique-xique                 xique xique
# 19                olhos d'agua                 olhos dagua
# 20      olho d'agua das flores       olho dagua das flores
# 21           sao jorge d'oeste            sao jorge doeste
# 22           aparecida d'oeste            aparecida doeste
# 23                  cipo-guacu                  cipo guacu
# 24          itaporanga d'ajuda           itaporanga dajuda
# 25             estrela d'oeste              estrela doeste
# 26                   varre-sai                   varre sai
# 27  governador dix-sept rosado  governador dix sept rosado
# 28       alta floresta d'oeste        alta floresta doeste
# 29            palmeira d'oeste             palmeira doeste
# 30                  mogi-mirim                  mogi mirim
# 31                  mogi-guacu                  mogi guacu
# 32           conquista d'oeste            conquista doeste
# 33              biritiba-mirim              biritiba mirim
# 34                 igarape-acu                 igarape acu
# 35              herval d'oeste               herval doeste
# 36            diamante d'oeste             diamante doeste
# 37       rancho alegre d'oeste        rancho alegre doeste
# 38                igarape-miri                igarape miri
# 39                  guarda-mor                  guarda mor
# 40                pingo-d'agua                 pingo dagua
# 41          sao joao d'alianca           sao joao dalianca
# 42               sapucai-mirim               sapucai mirim
# 43                   ji-parana                   ji parana
# 44               pariquera-acu               pariquera acu
# 45                 entre-ijuis                 entre ijuis
# 46       figueiropolis d'oeste        figueiropolis doeste
# 47                dias d'avila                 dias davila
# 48           itapejara d'oeste            itapejara doeste
# 49                  mae d'agua                   mae dagua
# 50      olho d'agua das cunhas       olho dagua das cunhas
# 51            alvorada d'oeste             alvorada doeste
# 52                   xangri-la                   xangri la

# %% [markdown]
# ### Removing Duplicates

# %%
# Final cleanup: Trimming whitespace and converting empty strings to Null.
customers_final_trim = trim_and_nullify_strings(customers_regional_suffixes)

# %%
# Check for duplicates
check_duplicates(customers_final_trim)
# Out:
# [Stage 201:=========================================================(1 + 0) / 1]
# ✅ No exact duplicate rows found. Every row is unique.

# %% [markdown]
# ✅ No exact duplicate rows found. Every row is unique.

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values in the final customers dataset.
customers_missing_values = check_missing_values(customers_final_trim)
print(customers_missing_values)
# Out:
# [Stage 210:>                                                        (0 + 1) / 1]
#                           missing_count  percentage
# customer_id                           0         0.0
# customer_unique_id                    0         0.0
# customer_zip_code_prefix              0         0.0
# customer_city                         0         0.0
# customer_state                        0         0.0
# customer_city_clean                   0         0.0

# %% [markdown]
# 🧩 No missing values in the final customers dataset.

# %% [markdown]
# ### Dropping the Dirty Column

# %%
# Step 1: Remove the original unrefined 'customer_city' column.
# Step 2: Promote the 'customer_city_clean' version to the original column name.
# Verified: The dataset is free of duplicate records and ready for the Silver Layer. ✅
customers_final_clean = customers_final_trim.drop("customer_city") \
    .withColumnRenamed("customer_city_clean", "customer_city")

# %%
# 🎲 Selecting 100 random examples for verification and quality check.
customers_final_clean.orderBy(F.rand()).limit(100).toPandas()
# Out:
#                          customer_id                customer_unique_id  \
# 0   2f7001da9e597c4b707313a341a20614  38c576114024f3c3e45f83e7b5ee0c56
# 1   e8ac9b27d2b90428825cedfe54b8c455  ff0d4869d957ba46496a840133691be6
# 2   8638b28024054f46722ade334452c048  8e2362db1bcd46ad2de37f1d63e7203e
# 3   4365561a2a4c1d768592aa0536e503c6  580c11d5df4eda0d717f716067b52de7
# 4   3909643728e469c11fe39b47013e93e9  7f94443aaca299f1234b9618d3f5805b
# 5   14e618e8adb379c1d9727e4cfb189daa  58b2572b34b182a7b5b04766a86bfb95
# 6   557680a586ced70b6898cbe01a35c87d  21bc36e41f9312e83d48bdba400f702d
# 7   438c7f59588a3d370200db20fb5c5a85  d4254847c058df4dbe92d4e6206da691
# 8   2004beab18003b04d2e2603e1055d589  d936da095a235937dbcc81ab08bac901
# 9   ece0add9b18630501bd9a4020bbf2637  5a740d409f9eed7b1051a2b08f8198a5
# 10  c5b0e8747809dbd77c33e961212674f4  ed023e1c2345f2703c7c14bca947e840
# 11  ebe02b455bc2f5f8828a89d8bd96cded  75a6e6bd47d77cea03442dc292d48b02
# 12  4013e6a6ae8c0476d72909e1f5de3d70  5127ad179e7992d6bd19b0107bfe3d60
# 13  5d83fb6702300aee684f3e30a1682754  b8649db3230d11e3747b83a461aabb62
# 14  16b4fe84e11d113214ba5bfc967bf782  3171b4d88a6e5197365277f56c7a9e7c
# 15  4865ae2e1e65f3f21f22e0d481915868  e82202695efe8aa20305248f9ca18c64
# 16  a4c1017188a10ac3de20036f363b7fe2  d394969c7455a2bbd8639fd450477d15
# 17  94e42ccb4c9e4e5003181fe0f7392003  432af692ebcbcc54e763cfc7c8001208
# 18  a35beaf9fec4fbac71efd9a2cd849683  7361b4cce726b898deb902ee3fe27f28
# 19  98ce198be4b03c0a9057329b3d3c3035  ac9a80a405cdd759de16b902ecc1cf32
# 20  bec4e5faf561fe6b4be44218d1cfd1c6  6df616876ef2151ab4a9d2e7f0632c1c
# 21  3f7a51e1e98b8842843f9e9c49d0721f  5de40556e64c68e511a1f01d00da8f4e
# 22  def82bd2aaf543e4a7ac20d87b8c5651  94a6a8ead5c42ee8c5e111f8e4aa5b78
# 23  8c6f1fc49db37c4c0b9224991a53223e  1e433d2aca7584032f8f56d51643e605
# 24  b2b424bf038e5ffd3dd24325a80529d9  c0df18dc82465a955273f3cae1145624
# 25  a0cad5d6079dc7c903506377dd1db7b7  04cb655245e109fea6aa9cfd48f168ce
# 26  5c13ef4a096ac39db6bc827024b66542  a990bc7a8233aecd2b556bff362bb44f
# 27  26edf51b99d1817a0d9890fc86cf8e63  966991f3fb9b67695c643670dafa8c7c
# 28  655db910cac0a44e6528240243b2f5cf  7b90167df4a4ce83f528b214f8c86676
# 29  9b0b194acbdf6bdf7bde206fff44c173  f96c22cb1c5244ef2e245ed6b249e7aa
# 30  8510621d67f7ec879641131a2d9b3e28  746022797b63585f20a286b45510a4b8
# 31  3d4b571062a7bb528ced4e8e11f095c0  5ec0a4b5c5c7ea2a5b62f97f746bd4e3
# 32  3c7b80343c2c11f71434110e462e3de1  ff4befb3408bb43643f743991ccd282c
# 33  6cd0023a7262f2b816862e3107508624  0b391e93cdb4fe7ad5446c111c647f9b
# 34  1e9b87abaaa43836c8dca222073a4b09  134381ba9753ac7b47b50259b1834938
# 35  dd6ff79fddc7e5fadda7b83b2bf4383b  1bd9ea0e69c784dfd93facf065b406d0
# 36  b792ed1781861557e76afc7d703807b6  82d2f1f1ab137487fa52f3b9df784c5f
# 37  dcf43e1fa6f118059382349530ff731d  1f0b4387cd8d90b3ede42b9b1440563b
# 38  1b0a218005553bbb622b569970807457  291c0ff050cf97149f73b6d78705b090
# 39  741488a61f59b1f0a0e02501db47fd8e  96b3b102cb9e8182d068806b7298549a
# 40  0040a8417928d0d5abd5169cd7877181  96e147852028a3ce1d25c86f03032023
# 41  8e9bba8e9800a9bdf85291c468b3607f  1fc5bf75325c996e6b257434eab88c3a
# 42  9d4f80182bcd5568a9a1df457fdde24b  3896294a5c51cceb8f670754ee49a172
# 43  4fdbaab85bcb2657b6b6c9fea1b0ccb6  e5a197b88d04fe99fe96b95f41a686f4
# 44  dcd8cf51c37cad018c9281d823889da8  81196f05712a31e3b612dc0056adfc9b
# 45  77c43b96370f1fc12c32a73629f20820  1583c58463188e24b34ad957e510d7f0
# 46  95c0c43f95b6e11a4ffae8f6d6877f74  0821fdf6e8db71ae96742f7676440779
# 47  9c3547e21265b2128066d941f6b1cf17  0751ebe1c05ef7a632934adae06c6d4a
# 48  3cac74b1c7dd18deaec3e1e772bcebb2  5d323409404dee6bdb0f6cf9ef828dae
# 49  7a1559fef97a80249f1a88e23b0155be  c53efd7066418285996351ab44147126
# 50  e2739b85af8403921b2b1bb2e99325df  3949a019223422cf30a6be3fc82f7982
# 51  0e04a0d0de3a7dd87a6d7a2931525f3b  139093b1c6e7e3108ac0469ce43bfb99
# 52  cc2799fcab7375793ea883dbed8a3141  90879b5ecd87add418bcb7e0ecb7ce1d
# 53  5a17549a68364d8fe0c4af22e7c83adc  66651cb1e94c5a4a6c080e415f425c3b
# 54  838bc2ff67963202eb29e748923c15fa  e8b82b7189d0161005e4bacb11e209ea
# 55  1b1aeca72c529981a8939da6859c4db9  859ebc00ccc39f92c05c0e0b3e35dcd6
# 56  7fe86e88a0583036d8c739b0a3988834  7463761aef43c2bf9b44ba212f8d7c9d
# 57  414e2ac71d455f634d69e610e2fd3b39  4b574b50f96b492fe261cc9755359f27
# 58  ab737335fd537457d0c8e5eb1dbf0539  6085ba35c922150b3fb3de397c6f9e94
# 59  35c919d9901b83235d3f9790ef39e7cb  30a51a0adb67d9b0ad6deda243b99318
# 60  61b417dee978cb372d39b4664901a10b  a00e899d273cdf688c72055f31576aa6
# 61  87f276c7f8462e63399bb1a70ea0496f  22f5499bc63c8ebcacf51cf02585eb37
# 62  5645f6b97d3740bc2846f27af1fe973f  034e7f551239546ae63e45d0b1186ab1
# 63  172d2893ff8f6ca8ca4a55100b8be48f  a4195ee2c2badfb9c4ff7678a7a175b0
# 64  34ed1c016090a8eb4ffac078c2abc343  7f4ecb1b7d84711ba1f4cca0618ba63b
# 65  6f8f59c663734b3f188aba68f54342c3  fa82add3040266ce63fb186c845f56ef
# 66  c047c68f42cf14e79adf7ff885415324  38505d03328fe209000f0bfee6709cf4
# 67  5ab0cf98530afe73920c05b432a8311a  cc8df0bacd74eef703f761bf52a32606
# 68  26ff2ad5fc82c54dc0784ff1819f82a0  3830512a5415f208e378c6728726ea3d
# 69  2f2c3d4159fa08183d294c682ac8dd63  d35bce9737b580ebcf54f58c24b6ad41
# 70  bf72b85664d38b97e6e3a21b6eb02b7f  772f0bc1ba1ce2b0a6cfa7603d7b1150
# 71  04f3fed63b02610ccf63aea0874d9b19  aa8804bf7d630692c09b03528f1fdedd
# 72  ed8015d79ac87082198750d415abd7b5  f9bf71aedf974324e6d89ce57f01ec45
# 73  551c3d5349e8367c1edcdf2ebcd1b47d  a061ea87fe96fc6b177a6201161c7847
# 74  216962229c0e00efdff1693996bb9ecb  2a9ac97120bc92da0e9281129ee45577
# 75  1b354261005ab5f5ff92c38c656c68a8  b43b320680e738c94f4692799dad0d92
# 76  a836f6725983cd79994904405fc070aa  8091492c09780918d5403f76f6132671
# 77  2a1dfb647f32f4390e7b857c67458536  5f7d7732b351ce851a158528581af05f
# 78  d5d2b40c4f46a961dd499fcf5541ffb8  b814324d11d2ba7ac4482460315dfb69
# 79  60f1def9b59b404aa3244246ae05bb94  66497ba44949e12429b9e0a1a4f867e2
# 80  6326318b4d693f609d4e83a029411dd5  68fd72e4ce9bf89e8aa222a940e29d7f
# 81  f2be8c3486681610dd9649534c41f7ae  c1d43ef6f70aff50201a1b882176a346
# 82  a45577149e2fb67976fd8a7385d54570  3ccd53395855932e15e05b77cfb60947
# 83  9719596a7621bf849efb0037dafdaa62  751b13868cb5061c32d2f7e0293f1be2
# 84  321ce37df9d56baeb8074da8de0b593a  7586515ee8846375909e8c9112dd0884
# 85  44da5e73b67c2ac30e15d54c879e050b  fe2c2aaa57ccd2a82d77a7168c3510e1
# 86  d709132e88f6504052afb042f4b7649d  5b8d3d205894a699082c1d6622f69fa9
# 87  5c70d6e3e98eb5c6f7dcbea674e6f836  83bcfeb972ccaa57c18425b7e67ff5b5
# 88  0d861a5e4dd6a9079d89e1330848f0ab  c8ed31310fc440a3f8031b177f9842c3
# 89  ef3ccd6d77b6f38823b6360f3f2216f9  89431b1ddf925a2453cc5e5ceca38327
# 90  adcb313ceaacab871bf8ff21a49108d6  5a00ad17554a6fe2e8388399a4af97f0
# 91  23e838b7e63651d981ace7ce4833bf84  da32e1c14e3bc9c13fb5d281a094221e
# 92  91e6102312e61bb955c6eb876c0972d1  948b476ec7d3987c7ea64a0e6c6617a4
# 93  34765ff1d45ff574aba9091a0c4ed223  f4002efe3f2ff5f9f323e888b8a6d6eb
# 94  08e51bf520ca8cdd5f95c5f38192598c  74b5b001e61c4a829aa9a0ebaa779f18
# 95  c08451aea5147d7bfe2f21b8bc444d76  9734a300e2ec028b45bcd4840c23a6e8
# 96  382b155c9a94793ddbd99d8f8b0887f8  de65189d40231f22bc5045a8b9842f00
# 97  c267e35a4a5aee75602d06f6860b25ba  53927ba64e0e05c38d81584e70986776
# 98  d0b0b2dd8bdaf36ebea19c232b4e986b  01a4788c8bd6d0d6a5b16ccdfd393b74
# 99  c5352fdf29b9b8a89f11338d0d1ce90d  d32cba0e07a87fa47d988ec46ee4c4ea
#
#    customer_zip_code_prefix customer_state            customer_city
# 0                     59965             rn               alexandria
# 1                     04726             sp                sao paulo
# 2                     18065             sp                 sorocaba
# 3                     38400             mg               uberlandia
# 4                     36240             mg            santos dumont
# 5                     15057             sp    sao jose do rio preto
# 6                     22450             rj           rio de janeiro
# 7                     73350             df                 brasilia
# 8                     23860             rj              mangaratiba
# 9                     13049             sp                 campinas
# 10                    22010             rj           rio de janeiro
# 11                    03167             sp                sao paulo
# 12                    08062             sp                sao paulo
# 13                    21321             rj           rio de janeiro
# 14                    60192             ce                fortaleza
# 15                    11471             sp                  guaruja
# 16                    30570             mg           belo horizonte
# 17                    03205             sp                sao paulo
# 18                    39100             mg               diamantina
# 19                    29101             es               vila velha
# 20                    06428             sp                  barueri
# 21                    13025             sp                 campinas
# 22                    02435             sp                sao paulo
# 23                    08461             sp                sao paulo
# 24                    18021             sp                 sorocaba
# 25                    16203             sp                  birigui
# 26                    95800             rs           venancio aires
# 27                    04513             sp                sao paulo
# 28                    13140             sp                 paulinia
# 29                    23087             rj           rio de janeiro
# 30                    30550             mg           belo horizonte
# 31                    68515             pa              parauapebas
# 32                    21320             rj           rio de janeiro
# 33                    11955             sp           barra do turvo
# 34                    65130             ma           paco do lumiar
# 35                    06050             sp                   osasco
# 36                    37550             mg             pouso alegre
# 37                    29164             es                    serra
# 38                    30240             mg           belo horizonte
# 39                    02365             sp                sao paulo
# 40                    12288             sp                 cacapava
# 41                    26433             rj                   japeri
# 42                    09688             sp    sao bernardo do campo
# 43                    08021             sp                sao paulo
# 44                    13273             sp                 valinhos
# 45                    62360             ce                 ibiapina
# 46                    05403             sp                sao paulo
# 47                    23028             rj           rio de janeiro
# 48                    22763             rj           rio de janeiro
# 49                    28911             rj                cabo frio
# 50                    01140             sp                sao paulo
# 51                    24240             rj                  niteroi
# 52                    36061             mg             juiz de fora
# 53                    18230             sp       sao miguel arcanjo
# 54                    68140             pa                   uruara
# 55                    41227             ba                 salvador
# 56                    09710             sp    sao bernardo do campo
# 57                    08331             sp                sao paulo
# 58                    09580             sp       sao caetano do sul
# 59                    35701             mg              sete lagoas
# 60                    96270             rs                mostardas
# 61                    13301             sp                      itu
# 62                    06767             sp          taboao da serra
# 63                    21540             rj           rio de janeiro
# 64                    30830             mg           belo horizonte
# 65                    13212             sp                  jundiai
# 66                    74690             go                  goiania
# 67                    35300             mg                caratinga
# 68                    27521             rj                  resende
# 69                    85170             pr                   pinhao
# 70                    26600             rj                paracambi
# 71                    24230             rj                  niteroi
# 72                    12524             sp            guaratingueta
# 73                    14882             sp              jaboticabal
# 74                    07792             sp                  cajamar
# 75                    11619             sp            sao sebastiao
# 76                    02802             sp                sao paulo
# 77                    54330             pe  jaboatao dos guararapes
# 78                    86140             pr         primeiro de maio
# 79                    18603             sp                 botucatu
# 80                    55730             pe               bom jardim
# 81                    74936             go     aparecida de goiania
# 82                    88015             sc            florianopolis
# 83                    72145             df                 brasilia
# 84                    13170             sp                   sumare
# 85                    89240             sc     sao francisco do sul
# 86                    87033             pr                  maringa
# 87                    05459             sp                sao paulo
# 88                    14610             sp                     ipua
# 89                    22775             rj           rio de janeiro
# 90                    15060             sp    sao jose do rio preto
# 91                    84990             pr                  arapoti
# 92                    04795             sp                sao paulo
# 93                    37540             mg    santa rita do sapucai
# 94                    85603             pr        francisco beltrao
# 95                    07417             sp                    aruja
# 96                    69919             ac               rio branco
# 97                    22251             rj           rio de janeiro
# 98                    28895             rj           rio das ostras
# 99                    79290             ms                   bonito

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data
# Analysis (EDA) and reporting stages.

# %%
# Storing the refined customers dataset to the Silver Layer in Parquet format
customers_final_clean.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_customers.parquet")

# %% [markdown]
# # ORDERS

# %%
# --- Define Orders Schema ---
orders_schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("order_status", StringType(), True),
    StructField("order_purchase_timestamp", TimestampType(), True),
    StructField("order_approved_at", TimestampType(), True),
    StructField("order_delivered_carrier_date", TimestampType(), True),
    StructField("order_delivered_customer_date", TimestampType(), True),
    StructField("order_estimated_delivery_date", TimestampType(), True)
])

# Load the dataset using the manual schema
orders = spark.read.format("csv") \
    .schema(orders_schema) \
    .option("header", "true") \
    .option("sep", ",") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("encoding", "UTF-8") \
    .option("multiLine", "true") \
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_orders_dataset.csv")

# %%
# Display schema
orders.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)

# %%
# Show first 5 rows
orders.limit(5).toPandas()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13
# 2                    2018-09-04
# 3                    2017-12-15
# 4                    2018-02-26

# %% [markdown]
# ### Trim String Columns

# %%
# Cleans the orders dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
orders_nullified_trimmed = trim_and_nullify_strings(orders)

# %% [markdown]
# ### Distinct Order Status

# %%
# Select the 'order_status' column and display only its unique (distinct) values
orders.select("order_status").distinct().toPandas()
# Out:
#   order_status
# 0      shipped
# 1     canceled
# 2     approved
# 3     invoiced
# 4      created
# 5    delivered
# 6  unavailable
# 7   processing

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values in the orders dataset.
orders_missing_values = check_missing_values(orders_nullified_trimmed)
print(orders_missing_values)
# Out:
# [Stage 7:>                                                          (0 + 1) / 1]
#                                missing_count  percentage
# order_id                                   0    0.000000
# customer_id                                0    0.000000
# order_status                               0    0.000000
# order_purchase_timestamp                   0    0.000000
# order_approved_at                        160    0.160899
# order_delivered_carrier_date            1783    1.793023
# order_delivered_customer_date           2965    2.981668
# order_estimated_delivery_date              0    0.000000

# %% [markdown]
# 🔍 Core columns like order_id are observed to be clean with no missing values. However, empty entries are noted in the delivery dates. These missing values will not be filled at this stage. Instead, they will be analyzed during the EDA phase to determine if the orders were canceled or if they are still being shipped.

# %%
# Import the specific functions from PySpark
from pyspark.sql.functions import min, max

# Display min and max purchase date
orders_nullified_trimmed.select(
    min("order_purchase_timestamp"), 
    max("order_purchase_timestamp")
).show()
# Out:
# +-----------------------------+-----------------------------+
# |min(order_purchase_timestamp)|max(order_purchase_timestamp)|
# +-----------------------------+-----------------------------+
# |          2016-09-04 21:15:19|          2018-10-17 17:30:18|
# +-----------------------------+-----------------------------+

# %% [markdown]
# The dataset covers the order period from 2016 to 2018.

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data
# Analysis (EDA) and reporting stages.

# %%
# Storing the refined orders dataset to the Silver Layer in Parquet format
orders_nullified_trimmed.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_orders.parquet")

# %% [markdown]
# # ORDER ITEMS

# %% [markdown]
# This table uses a Composite Primary Key composed of (order_id, order_item_id).
# 🛒 **order_id:** Identifies the transaction.
# 🛍️ **order_item_id:** A sequential number identifying each product within that transaction.
#
# Both columns must be used to uniquely identify a specific row or to join accurately.

# %%
# --- Define Order Items Schema ---
order_items_schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("order_item_id", IntegerType(), True),
    StructField("product_id", StringType(), True),
    StructField("seller_id", StringType(), True),
    StructField("shipping_limit_date", TimestampType(), True),
    StructField("price", DecimalType(10, 2), True),
    StructField("freight_value", DecimalType(10, 2), True)
])

# Load the dataset using the manual schema
order_items = spark.read.format("csv") \
    .schema(order_items_schema) \
    .option("header", "true") \
    .option("sep", ",") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("encoding", "UTF-8") \
    .option("multiLine", "true") \
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_order_items_dataset.csv")

# %%
# Display schema
order_items.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_item_id: integer (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- shipping_limit_date: timestamp (nullable = true)
#  |-- price: decimal(10,2) (nullable = true)
#  |-- freight_value: decimal(10,2) (nullable = true)

# %%
# Show first 5 rows
order_items.limit(5).toPandas()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price freight_value
# 0 2017-09-19 09:45:35   58.90         13.29
# 1 2017-05-03 11:05:13  239.90         19.93
# 2 2018-01-18 14:48:30  199.00         17.87
# 3 2018-08-15 10:10:18   12.99         12.79
# 4 2017-02-13 13:57:51  199.90         18.14

# %%
# Total number of records
order_items.count()
# Out:
# 112650

# %% [markdown]
# ### Trim String Columns

# %%
# Cleans the order items dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
order_items_nullified_trimmed = trim_and_nullify_strings(order_items)

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values 
order_items_missing_values = check_missing_values(order_items_nullified_trimmed)
print(order_items_missing_values)
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
#                      missing_count  percentage
# order_id                         0         0.0
# order_item_id                    0         0.0
# product_id                       0         0.0
# seller_id                        0         0.0
# shipping_limit_date              0         0.0
# price                            0         0.0
# freight_value                    0         0.0

# %% [markdown]
# 🧩 No missing values in the final order items dataset.

# %% [markdown]
# ### 📊 Statistical Summary

# %%
order_items_stats = order_items_nullified_trimmed.select(
    "price", 
    "freight_value", 
).summary("count", "mean", "stddev", "min", "50%", "max")

order_items_stats.show()
# Out:
# +-------+-----------------+------------------+
# |summary|            price|     freight_value|
# +-------+-----------------+------------------+
# |  count|           112650|            112650|
# |   mean|       120.653739|         19.990320|
# | stddev|183.6339280502597|15.806405412296998|
# |    min|             0.85|              0.00|
# |    50%|            74.99|             16.26|
# |    max|          6735.00|            409.68|
# +-------+-----------------+------------------+

# %% [markdown]
# 🕵️ The **freight_value** column contains a minimum value of **0.00**.
# This confirms the presence of free shipping transactions in the dataset.

# %%
# Calculating the minimum and maximum shipping dates
date_range = order_items.agg(
    F.min("shipping_limit_date").alias("earliest_date"),
    F.max("shipping_limit_date").alias("latest_date")
)

date_range.toPandas()
# Out:
#         earliest_date         latest_date
# 0 2016-09-19 00:15:34 2020-04-09 22:35:08

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data
# Analysis (EDA) and reporting stages.

# %%
# Storing the refined order items dataset to the Silver Layer in Parquet format
order_items_nullified_trimmed.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_order_items.parquet")

# %% [markdown]
# # ORDER PAYMENTS

# %%
# --- Define Order Payments Schema ---
order_payments_schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("payment_sequential", IntegerType(), True),
    StructField("payment_type", StringType(), True),
    StructField("payment_installments", IntegerType(), True),
    StructField("payment_value", DecimalType(10, 2), True) 
])

# Load the dataset using the manual schema
order_payments = spark.read.format("csv") \
    .schema(order_payments_schema) \
    .option("header", "true") \
    .option("sep", ",") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("encoding", "UTF-8") \
    .option("multiLine", "true") \
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_order_payments_dataset.csv")

# %%
# Display Schema
order_payments.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: decimal(10,2) (nullable = true)

# %% [markdown]
# 💳 Payment Columns:
# **order_id:** Unique order identifier.
# **payment_sequential:** Sequence number for multiple payment methods per order.
# **payment_type:** Method of payment (e.g., credit card, voucher).
# **payment_installments:** Number of installments selected by the customer.
# **payment_value:** Total transaction value for this specific payment method.

# %%
# Show first 5 rows
order_payments.limit(5).toPandas()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments payment_value
# 0                     8         99.33
# 1                     1         24.39
# 2                     1         65.71
# 3                     8        107.78
# 4                     2        128.45

# %% [markdown]
# ### Trim String Columns

# %%
# Cleans the order payments dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
order_payments_nullified_trimmed = trim_and_nullify_strings(order_payments)

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values in the order payments dataset.
order_payments_missing_values = check_missing_values(order_payments_nullified_trimmed)
print(order_payments_missing_values)
# Out:
#                       missing_count  percentage
# order_id                          0         0.0
# payment_sequential                0         0.0
# payment_type                      0         0.0
# payment_installments              0         0.0
# payment_value                     0         0.0

# %% [markdown]
# 🧩 No missing values in the final order payments dataset.

# %% [markdown]
# ### 📊 Statistical Summary

# %%
order_payments_stats = order_payments_nullified_trimmed.select(
    "payment_value", 
    "payment_installments", 
    "payment_sequential"
).summary("count", "mean", "stddev", "min", "50%", "max")

order_payments_stats.show()
# Out:
# 26/02/16 10:34:54 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 20:>                                                         (0 + 1) / 1]
# +-------+------------------+--------------------+------------------+
# |summary|     payment_value|payment_installments|payment_sequential|
# +-------+------------------+--------------------+------------------+
# |  count|            103886|              103886|            103886|
# |   mean|        154.100380|   2.853348863176944|1.0926785129853878|
# | stddev|217.49406386472384|   2.687050673856486|0.7065837791949948|
# |    min|              0.00|                   0|                 1|
# |    50%|             100.0|                   1|                 1|
# |    max|          13664.08|                  24|                29|
# +-------+------------------+--------------------+------------------+

# %% [markdown]
# ⚠️ **Anomaly:** Found 'payment_installments' = 0 (see statistical summary). Business logic requires a minimum of 1. These records may indicate technical glitches or failed vouchers.
#
# ✅ Retaining records despite logical inconsistencies in **payment_sequential** and **payment_installments**.
# Deletion would lead to revenue underreporting (sum of payment_value).
# Prioritizing financial data integrity over sequence perfection to ensure accurate sales aggregation.

# %%
# Filter rows where payment_installments is 0
order_payments_nullified_trimmed.filter(F.col("payment_installments") == 0).toPandas()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  744bade1fcf9ff3f31d860ace076d422                   2  credit_card
# 1  1a57108394169c0b47d8f876acc9ba2d                   2  credit_card
#
#    payment_installments payment_value
# 0                     0         58.69
# 1                     0        129.94

# %%
# Specific list of IDs
target_ids = ["744bade1fcf9ff3f31d860ace076d422", "1a57108394169c0b47d8f876acc9ba2d"]

# Fix inconsistencies in payment_sequential and payment_installments
order_payments_fixed_payment_installments = order_payments_nullified_trimmed.withColumn(
    "payment_installments",
    F.when(F.col("order_id").isin(target_ids), 1).otherwise(F.col("payment_installments"))
)

order_payments_fixed_payment_sequential = order_payments_fixed_payment_installments.withColumn(
    "payment_sequential",
    F.when(F.col("order_id").isin(target_ids), 1).otherwise(F.col("payment_sequential"))
)

# %%
# Validation: Check for payment_installments to verify if the fixing prcess was successful.
order_payments_fixed_payment_sequential.filter(F.col("payment_installments") == 0).toPandas()
# Out:
# Empty DataFrame
# Columns: [order_id, payment_sequential, payment_type, payment_installments, payment_value]
# Index: []

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data Analysis (EDA) and reporting stages.

# %%
# Storing the refined order payments dataset to the Silver Layer in Parquet format
order_payments_fixed_payment_sequential.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_order_payments.parquet")

# %% [markdown]
# # ORDER REVIEWS

# %%
# --- Define Order Reviews Schema ---
order_reviews_schema = StructType([
    StructField("review_id", StringType(), True),
    StructField("order_id", StringType(), True),
    StructField("review_score", IntegerType(), True),
    StructField("review_comment_title", StringType(), True),
    StructField("review_comment_message", StringType(), True),
    StructField("review_creation_date", TimestampType(), True),
    StructField("review_answer_timestamp", TimestampType(), True)
])

# Load the dataset using the manual schema
order_reviews = spark.read.format("csv") \
    .schema(order_reviews_schema) \
    .option("header", "true") \
    .option("sep", ",") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("encoding", "UTF-8") \
    .option("multiLine", "true") \
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_order_reviews_dataset.csv")

# %%
# Display Schema
order_reviews.printSchema()
# Out:
# root
#  |-- review_id: string (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- review_score: integer (nullable = true)
#  |-- review_comment_title: string (nullable = true)
#  |-- review_comment_message: string (nullable = true)
#  |-- review_creation_date: timestamp (nullable = true)
#  |-- review_answer_timestamp: timestamp (nullable = true)

# %%
# Show first 5 rows
order_reviews.limit(5).toPandas()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                 None
# 1             5                 None
# 2             5                 None
# 3             5                 None
# 4             5                 None
#
#                               review_comment_message review_creation_date  \
# 0                                               None           2018-01-18
# 1                                               None           2018-03-10
# 2                                               None           2018-02-17
# 3              Recebi bem antes do prazo estipulado.           2017-04-21
# 4  Parabéns lojas lannister adorei comprar pela I...           2018-03-01
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# ### Trim String Columns

# %%
# Cleans the order reviews dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
order_reviews_nullified_trimmed = trim_and_nullify_strings(order_reviews)

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values in the order reviews dataset.
order_reviews_missing_values = check_missing_values(order_reviews_nullified_trimmed)
print(order_reviews_missing_values)
# Out:
# [Stage 29:>                                                         (0 + 1) / 1]
#                          missing_count  percentage
# review_id                            0    0.000000
# order_id                             0    0.000000
# review_score                         0    0.000000
# review_comment_title             87658   88.343546
# review_comment_message           58256   58.711602
# review_creation_date                 0    0.000000
# review_answer_timestamp              0    0.000000

# %% [markdown]
# ⚠️ Analysis shows that **review_score** has **no missing values**, while text fields
# **review_comment_title**, **review_comment_message** contain nulls.
# No imputation will be performed since these columns are reserved for future analysis.

# %% [markdown]
# ### 📊 Statistical Summary

# %%
order_reviews_stats = order_reviews_nullified_trimmed.select(
    "review_score"
).summary("count", "mean", "stddev", "min", "50%", "max")

order_reviews_stats.show()
# Out:
# [Stage 48:>                                                         (0 + 1) / 1]
# +-------+------------------+
# |summary|      review_score|
# +-------+------------------+
# |  count|             99224|
# |   mean|  4.08642062404257|
# | stddev|1.3475791311150984|
# |    min|                 1|
# |    50%|                 5|
# |    max|                 5|
# +-------+------------------+

# %% [markdown]
# 📊 Statistical summary of 'review_score' indicates a valid range [1, 5] with no anomalies or outliers detected.

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data Analysis (EDA) and reporting stages.

# %%
# Storing the refined order reviews dataset to the Silver Layer in Parquet format
order_reviews_nullified_trimmed.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_order_reviews.parquet")

# %% [markdown]
# # PRODUCTS

# %%
# --- Define Products Schema ---
products_schema = StructType([
    StructField("product_id", StringType(), True),
    StructField("product_category_name", StringType(), True),
    StructField("product_name_lenght", IntegerType(), True),
    StructField("product_description_lenght", IntegerType(), True),
    StructField("product_photos_qty", IntegerType(), True),
    StructField("product_weight_g", IntegerType(), True),
    StructField("product_length_cm", IntegerType(), True),
    StructField("product_height_cm", IntegerType(), True),
    StructField("product_width_cm", IntegerType(), True)
])

# Load the dataset using the manual schema
products = spark.read.format("csv") \
    .schema(products_schema) \
    .option("header", "true") \
    .option("sep", ",") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("encoding", "UTF-8") \
    .option("multiLine", "true") \
    .load("/opt/examples/datasets/brazilian_ecommerce/olist_products_dataset.csv")

# %%
# Display schema
products.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)

# %%
# Show first 5 rows
products.limit(5).toPandas()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                   40                         287                   1
# 1                   44                         276                   1
# 2                   46                         250                   1
# 3                   27                         261                   1
# 4                   37                         402                   4
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0               225                 16                 10                14
# 1              1000                 30                 18                20
# 2               154                 18                  9                15
# 3               371                 26                  4                26
# 4               625                 20                 17                13

# %% [markdown]
# ### Trim String Columns

# %%
# Cleans the products dataset by removing leading/trailing whitespace and 
# converting empty or blank strings into proper NULL (None) values.
products_nullified_trimmed = trim_and_nullify_strings(products)

# %% [markdown]
# ### Product Category Name Translation

# %%
# --- Define Products Translation Schema ---
products_translation_schema = StructType([
    StructField("product_category_name", StringType(), True),
    StructField("product_category_name_english", StringType(), True),
])

# Load the dataset using the manual schema
products_translation = spark.read.format("csv") \
    .schema(products_translation_schema) \
    .option("header", "true") \
    .option("sep", ",") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .option("encoding", "UTF-8") \
    .option("multiLine", "true") \
    .load("/opt/examples/datasets/brazilian_ecommerce/product_category_name_translation.csv")

# %%
# Display schema
products_translation.printSchema()
# Out:
# root
#  |-- product_category_name: string (nullable = true)
#  |-- product_category_name_english: string (nullable = true)

# %%
# Show first 5 rows
products_translation.limit(5).toPandas()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
# Apply trimming to remove whitespace and convert empty strings to NULL values
products_translation_nullified_trimmed = trim_and_nullify_strings(products_translation)

# %% [markdown]
# ### Joining Tables for English Product Names

# %%
# Joining tables
products_translated = products_nullified_trimmed.join(
    products_translation_nullified_trimmed, 
    on="product_category_name", 
    how="left"
)

# %%
# Preview the results
products_translated.limit(5).toPandas()
# Out:
#    product_category_name                        product_id  \
# 0             perfumaria  1e9e8ef04dbcff4541ed26657ea517e5
# 1                  artes  3aa071139cb16b67ca9e5dea641aaa2f
# 2          esporte_lazer  96bd76ec8810374ed1b65e291975717f
# 3                  bebes  cef67bcfe19066a932b7673e239eb23d
# 4  utilidades_domesticas  9dc1a7de274444849c219cff195d0b71
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                   40                         287                   1
# 1                   44                         276                   1
# 2                   46                         250                   1
# 3                   27                         261                   1
# 4                   37                         402                   4
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0               225                 16                 10                14
# 1              1000                 30                 18                20
# 2               154                 18                  9                15
# 3               371                 26                  4                26
# 4               625                 20                 17                13
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values 
products_missing_values = check_missing_values(products_translated)
print(products_missing_values)
# Out:
#                                missing_count  percentage
# product_category_name                    610    1.851234
# product_id                                 0    0.000000
# product_name_lenght                      610    1.851234
# product_description_lenght               610    1.851234
# product_photos_qty                       610    1.851234
# product_weight_g                           2    0.006070
# product_length_cm                          2    0.006070
# product_height_cm                          2    0.006070
# product_width_cm                           2    0.006070
# product_category_name_english            623    1.890686

# %% [markdown]
# 🚨 The product_category_name_english column has **623** missing values, which is **13 more** than the original category column.

# %% [markdown]
# ⚠️ Missing values in **product_category_name** and **product_category_name_english** will be handled as it is a key feature.
# Other columns such as 'product_name_lenght' or 'product_photos_qty' will be ignored for now
# as they are not required for the upcoming steps of this EDA.

# %% [markdown]
# ### Handling Missing Values

# %%
# This filter identifies products that have a name in the original language 
# but are missing the English translation.

missing_translations = products_translated.filter(
    F.col('product_category_name').isNotNull() & 
    F.col('product_category_name_english').isNull()
)

# To see the unique values
missing_translations.select('product_category_name').distinct().toPandas()
# Out:
#                            product_category_name
# 0                                       pc_gamer
# 1  portateis_cozinha_e_preparadores_de_alimentos

# %% [markdown]
# 🚨 **MANUAL MAPPING:** Fixing the 13 missing English translations.
# The following entries in **product_category_name** are updated in the product_category_name_english column as follows:
# **pc_gamer -> pc_gamer
# portateis_cozinha_e_preparadores_de_alimentos -> kitchen_portables_and_food_preparators**

# %%
# Updating the English column
products_translated_missing_13 = products_translated.withColumn(
    'product_category_name_english',
    F.when(
        F.col('product_category_name') == 'pc_gamer', 
        'pc_gamer' # Rule 1: If it's pc_gamer, keep it as pc_gamer
    ).when(
        F.col('product_category_name') == 'portateis_cozinha_e_preparadores_de_alimentos', 
        'kitchen_portables_and_food_preparators' # Rule 2: Translate this long name
    ).otherwise(
        F.col('product_category_name_english') # Otherwise: Don't change anything!
    )
)

# %%
# Check for missing values 
products_missing_values = check_missing_values(products_translated_missing_13)
print(products_missing_values)
# Out:
#                                missing_count  percentage
# product_category_name                    610    1.851234
# product_id                                 0    0.000000
# product_name_lenght                      610    1.851234
# product_description_lenght               610    1.851234
# product_photos_qty                       610    1.851234
# product_weight_g                           2    0.006070
# product_length_cm                          2    0.006070
# product_height_cm                          2    0.006070
# product_width_cm                           2    0.006070
# product_category_name_english            610    1.851234

# %%
# Identifying rows where both category columns are empty.
missing_translations = products_translated_missing_13.filter(
    F.col('product_category_name').isNull() & 
    F.col('product_category_name_english').isNull()
)

# To see the unique values
missing_translations.select('product_category_name').count()
# Out:
# 610

# %% [markdown]
# There are 610 instances where both fields are missing simultaneously.

# %%
# Fill null values with 'unknown' in the specified columns
products_translated_handled_missing = products_translated_missing_13.fillna(
    value='unknown', 
    subset=['product_category_name', 'product_category_name_english']
)

# %%
# Validation: Check for product_category_name to verify if the filling process was successful.
products_missing_values = check_missing_values(products_translated_handled_missing)
print(products_missing_values)
# Out:
#                                missing_count  percentage
# product_category_name                      0    0.000000
# product_id                                 0    0.000000
# product_name_lenght                      610    1.851234
# product_description_lenght               610    1.851234
# product_photos_qty                       610    1.851234
# product_weight_g                           2    0.006070
# product_length_cm                          2    0.006070
# product_height_cm                          2    0.006070
# product_width_cm                           2    0.006070
# product_category_name_english              0    0.000000

# %% [markdown]
# 🧩 Missing values in **product_category_name** and **product_category_name_english** colums are handled.

# %% [markdown]
# ### Duplicated Rows

# %%
# Check for duplicate records in the products dataset
check_duplicates(products_translated_handled_missing)
# Out:
# [Stage 74:>                                                         (0 + 1) / 1]
# ✅ No exact duplicate rows found. Every row is unique.

# %% [markdown]
# ✅ No exact duplicate rows found. Every row is unique.

# %% [markdown]
# ### 📊 Statistical Summary

# %%
# Select the numerical columns from the products table
products_numerical_stats = products_translated_handled_missing.select(
    "product_name_lenght",
    "product_description_lenght",
    "product_photos_qty",
    "product_weight_g",
    "product_length_cm",
    "product_height_cm",
    "product_width_cm"
).summary("count", "mean", "stddev", "min", "50%", "max")

# Display the statistics
products_numerical_stats.toPandas()
# Out:
#   summary product_name_lenght product_description_lenght  product_photos_qty  \
# 0   count               32341                      32341               32341
# 1    mean   48.47694876472589          771.4952846232337  2.1889861166939797
# 2  stddev  10.245740725237287          635.1152246349538  1.7367656379315435
# 3     min                   5                          4                   1
# 4     50%                  51                        595                   1
# 5     max                  76                       3992                  20
#
#      product_weight_g   product_length_cm   product_height_cm  \
# 0               32949               32949               32949
# 1  2276.4724877841513   30.81507784758263  16.937661234028347
# 2   4282.038730977024  16.914458054065953  13.637554061749569
# 3                   0                   7                   2
# 4                 700                  25                  13
# 5               40425                 105                 105
#
#      product_width_cm
# 0               32949
# 1  23.196728277034204
# 2  12.079047453227794
# 3                   6
# 4                  20
# 5                 118

# %% [markdown]
# 🔍 Preliminary check of min/max values; no obvious anomalies observed.
# A comprehensive statistical analysis will be performed during the EDA stage.

# %% [markdown]
# ### 🕵️  Final validation: Reviewing product names to ensure transformation were applied correctly.

# %%
# Retrieving unique rows for product names
products_translated_handled_missing.select("product_category_name", "product_category_name_english").distinct().toPandas()
# Out:
#                              product_category_name  \
# 0                                       automotivo
# 1                                              pcs
# 2                                  eletroportateis
# 3                                 moveis_decoracao
# 4                          fashion_roupa_masculina
# 5                                     beleza_saude
# 6                           informatica_acessorios
# 7                           livros_interesse_geral
# 8                                            artes
# 9                                      eletronicos
# 10                                        pc_gamer
# 11                                malas_acessorios
# 12                                         unknown
# 13                                      la_cuisine
# 14                               artigos_de_festas
# 15                     portateis_casa_forno_e_cafe
# 16                                  telefonia_fixa
# 17                                 casa_conforto_2
# 18                                   esporte_lazer
# 19                   industria_comercio_e_negocios
# 20                                    dvds_blu_ray
# 21                                      brinquedos
# 22                                       alimentos
# 23                                      cool_stuff
# 24                                   casa_conforto
# 25                                  consoles_games
# 26                                          flores
# 27                                fashion_calcados
# 28                                   moveis_quarto
# 29                                       telefonia
# 30               construcao_ferramentas_construcao
# 31                         sinalizacao_e_seguranca
# 32                                 livros_tecnicos
# 33                                eletrodomesticos
# 34                     fashion_bolsas_e_acessorios
# 35              construcao_ferramentas_ferramentas
# 36                                     moveis_sala
# 37                               alimentos_bebidas
# 38                               cds_dvds_musicais
# 39                                          musica
# 40                          fashion_roupa_feminina
# 41                           instrumentos_musicais
# 42                           utilidades_domesticas
# 43                                    market_place
# 44                                           audio
# 45                  fashion_underwear_e_moda_praia
# 46   portateis_cozinha_e_preparadores_de_alimentos
# 47                               livros_importados
# 48                              artes_e_artesanato
# 49                              seguros_e_servicos
# 50                                         bebidas
# 51                              eletrodomesticos_2
# 52  moveis_cozinha_area_de_servico_jantar_e_jardim
# 53                               moveis_escritorio
# 54                                 cama_mesa_banho
# 55                       agro_industria_e_comercio
# 56                              relogios_presentes
# 57                                      perfumaria
# 58                       moveis_colchao_e_estofado
# 59                                 fraldas_higiene
# 60                              ferramentas_jardim
# 61                                        pet_shop
# 62                                    climatizacao
# 63                   fashion_roupa_infanto_juvenil
# 64                                           bebes
# 65                                artigos_de_natal
# 66                   construcao_ferramentas_jardim
# 67                construcao_ferramentas_seguranca
# 68                                 fashion_esporte
# 69                        tablets_impressao_imagem
# 70                                       papelaria
# 71               construcao_ferramentas_iluminacao
# 72                                       cine_foto
# 73                                 casa_construcao
#
#               product_category_name_english
# 0                                      auto
# 1                                 computers
# 2                          small_appliances
# 3                           furniture_decor
# 4                     fashion_male_clothing
# 5                             health_beauty
# 6                     computers_accessories
# 7                    books_general_interest
# 8                                       art
# 9                               electronics
# 10                                 pc_gamer
# 11                      luggage_accessories
# 12                                  unknown
# 13                               la_cuisine
# 14                           party_supplies
# 15    small_appliances_home_oven_and_coffee
# 16                          fixed_telephony
# 17                           home_comfort_2
# 18                           sports_leisure
# 19           industry_commerce_and_business
# 20                             dvds_blu_ray
# 21                                     toys
# 22                                     food
# 23                               cool_stuff
# 24                             home_confort
# 25                           consoles_games
# 26                                  flowers
# 27                            fashion_shoes
# 28                        furniture_bedroom
# 29                                telephony
# 30          construction_tools_construction
# 31                   signaling_and_security
# 32                          books_technical
# 33                          home_appliances
# 34                 fashion_bags_accessories
# 35                  costruction_tools_tools
# 36                    furniture_living_room
# 37                               food_drink
# 38                        cds_dvds_musicals
# 39                                    music
# 40                   fashio_female_clothing
# 41                      musical_instruments
# 42                               housewares
# 43                             market_place
# 44                                    audio
# 45                  fashion_underwear_beach
# 46   kitchen_portables_and_food_preparators
# 47                           books_imported
# 48                    arts_and_craftmanship
# 49                    security_and_services
# 50                                   drinks
# 51                        home_appliances_2
# 52  kitchen_dining_laundry_garden_furniture
# 53                         office_furniture
# 54                           bed_bath_table
# 55               agro_industry_and_commerce
# 56                            watches_gifts
# 57                                perfumery
# 58        furniture_mattress_and_upholstery
# 59                      diapers_and_hygiene
# 60                             garden_tools
# 61                                 pet_shop
# 62                         air_conditioning
# 63                fashion_childrens_clothes
# 64                                     baby
# 65                       christmas_supplies
# 66                 costruction_tools_garden
# 67                construction_tools_safety
# 68                            fashion_sport
# 69                   tablets_printing_image
# 70                               stationery
# 71                construction_tools_lights
# 72                               cine_photo
# 73                        home_construction

# %% [markdown]
#  ✅ Mapping validation successful; all product categories have been correctly translated to their English counterparts.

# %% [markdown]
# ### Dropping the Original Portuguese Product Name Column

# %%
# Drop the original Portuguese product category name column and rename the English version for consistency.
products_final_clean = products_translated_handled_missing.drop("product_category_name") \
    .withColumnRenamed("product_category_name_english", "product_category_name")

# %%
# Finalized Silver Layer dataset for products is ready for EDA.
products_final_clean.limit(10).toPandas()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                   40
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   44
# 2  96bd76ec8810374ed1b65e291975717f                   46
# 3  cef67bcfe19066a932b7673e239eb23d                   27
# 4  9dc1a7de274444849c219cff195d0b71                   37
# 5  41d3672d4792049fa1779bb35283ed13                   60
# 6  732bd381ad09e530fe0a5f457d81becb                   56
# 7  2548af3e6e77a690cf3eb6368e9ab61e                   56
# 8  37cc742be07708b53a98702e77a21a02                   57
# 9  8c92109888e8cdf9d66dc7e463025574                   36
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                         287                   1               225
# 1                         276                   1              1000
# 2                         250                   1               154
# 3                         261                   1               371
# 4                         402                   4               625
# 5                         745                   1               200
# 6                        1272                   4             18350
# 7                         184                   2               900
# 8                         163                   1               400
# 9                        1156                   1               600
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0                 16                 10                14
# 1                 30                 18                20
# 2                 18                  9                15
# 3                 26                  4                26
# 4                 20                 17                13
# 5                 38                  5                11
# 6                 70                 24                44
# 7                 40                  8                40
# 8                 27                 13                17
# 9                 17                 10                12
#
#   product_category_name
# 0             perfumery
# 1                   art
# 2        sports_leisure
# 3                  baby
# 4            housewares
# 5   musical_instruments
# 6            cool_stuff
# 7       furniture_decor
# 8       home_appliances
# 9                  toys

# %% [markdown]
# ### 🥈 Silver Layer: Storing Refined Data
# The data cleaning and transformation phase is now complete. In this step, the refined and validated dataset is being persisted into the Silver Layer. This provides a reliable and high-quality foundation for the upcoming Exploratory Data Analysis (EDA) and reporting stages.

# %%
# Storing the refined products dataset to the Silver Layer in Parquet format
products_final_clean.write.mode("overwrite") \
    .parquet("/opt/examples/datasets/brazilian_ecommerce/silver/olist_products.parquet")

# %% [markdown]
# ✅ All data cleaning and transformation tasks for the Olist E-commerce dataset are finalized. The processed tables have been stored into the Silver Layer.
#
# **Next Step:** Transitioning to **Exploratory Data Analysis (EDA)** to uncover trends, customer behavior patterns, and operational insights. 🔍🚀
